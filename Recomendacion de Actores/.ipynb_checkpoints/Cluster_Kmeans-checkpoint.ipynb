# %%
import pandas as pd
import unidecode as uni
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

def generar_vecinos(p_data):
    data = p_data
    
    df2 = pd.get_dummies(data.Name)
    df3 = data[['fecha_anio']]
    
    df = pd.concat([df2,df3],axis=1)
    df = df.dropna()
    X = np.array(df)
    KMeans_ = KMeans(n_clusters=150, n_init=2,init='random',random_state=0).fit(X)

    
    return pd.Series(KMeans_.labels_)

# %% [markdown]
# ## UNIR DATASETS DE ACTORES CON PELICULAS

# %%
creador = pd.read_csv('Creator.csv')
person = pd.read_csv('Person.csv')
creador_person = creador.merge(person,how='inner',left_on='IDPerson', right_on='ID')
nom_individual = pd.read_csv('AwardNominationIndividual.csv')
creador_person['IDPerson'] = creador_person.IDPerson[creador_person.IDPerson.notnull()].astype(int)
creador_person_nom_indv = creador_person.merge(nom_individual,how='inner',left_on='IDPerson',right_on='IDPerson')
creador_person_nom_indv = creador_person_nom_indv[['IDMovie','Importance','IDPerson','Role','FullName','Winner','Category']]
nom_creador = pd.read_csv('AwardNominationCreator.csv')
creador_person_nom = creador_person_nom_indv.merge(nom_creador,how='left',left_on='IDPerson',right_on='IDCreator')
creador_person_nom_creador = pd.concat([creador_person_nom.iloc[:,:7],creador_person_nom[['Winner_y','Category_y','IDCreator']]],axis=1)
movieGenre = pd.read_csv('MovieGenre.csv')
movie = pd.read_csv('Movie.csv')
movie_genre = movie.merge(movieGenre,how='inner',left_on='ID',right_on='IDMovie')
genre = pd.read_csv('Genre.csv')
movie_genre = movie_genre.merge(genre,how='inner',left_on='IDGenre',right_on='id')
movie_genre = movie_genre[['ID','RuntimeMinutes','Title','Name']]
movie_actor = movie_genre.merge(creador_person_nom,how='inner',left_on='ID',right_on='IDMovie')
movies_metadata = pd.read_csv('movies_metadata.csv')
movie_actor['Title'] = movie_actor.Title.astype(str).apply(uni.unidecode).str.lower()
movies_metadata['original_title'] = movies_metadata.original_title.astype(str).apply(uni.unidecode).str.lower()
movies_metadata = movies_metadata[['adult','budget','release_date','revenue','popularity','original_title']]
movie_actor_metadata = movie_actor.merge(movies_metadata,how='inner',left_on='Title',right_on='original_title')
df_actores = movie_actor_metadata[movie_actor_metadata.Role.str.contains('actor')]
df_tecnicos = movie_actor_metadata[~(movie_actor_metadata.Role.str.contains('actor'))]
df_actores = df_actores[df_actores.Category_x.str.contains('act')]
df_actores['Winner_y'] = df_actores.Winner_y.fillna('Sin Nominacion')
df_actores['Winner_x'] = df_actores.Winner_x.fillna('Sin Nominacion')
df_tecnicos['Winner_y'] = df_tecnicos.Winner_y.fillna('Sin Nominacion')
df_tecnicos['Winner_x'] = df_tecnicos.Winner_x.fillna('Sin Nominacion')
df_actores_premios = df_actores[['Title','FullName','Winner_x']]
df_actores_premios['Winner_x'] = df_actores_premios.Winner_x.apply(lambda x: 1 if x else 0)
data_apropiado = pd.read_csv('data_apropiado.csv',sep='|').iloc[:,1:]
data_apropiado = data_apropiado.drop_duplicates()
df_actores = df_actores.merge(data_apropiado,how='left',left_on='Title',right_on='Title')
df_actores['Winner_x'] = df_actores.Winner_x.apply(lambda x: 1 if x else 0)
premios_por_actor = pd.DataFrame(df_actores.groupby(['FullName'])['Winner_x'].sum()).reset_index()
premios_por_actor = premios_por_actor.drop_duplicates()
df_actores = df_actores.merge(premios_por_actor,how='left',left_on='FullName',right_on='FullName')
df_actores['Winner_x_y'] = pd.qcut(df_actores.Winner_x_y,2,labels=[0,1])
df_actores['fecha_anio'] = df_actores.release_date[df_actores.release_date.notnull()].str.split(pat='-').apply(lambda x: x[0])
df_actores = df_actores[['Title','budget','FullName','apropiado','Name','fecha_anio','RuntimeMinutes','Winner_x_y']]
df_actores = df_actores.dropna()
df_actores = df_actores.drop_duplicates()
df_actores = df_actores.reset_index().iloc[:,1:]
df_actores['cluster_kmeans'] = pd.Series(generar_vecinos(df_actores))
df_actores = df_actores[df_actores.budget.astype(int)>0]
df_actores_cluster = df_actores[['Title','cluster_kmeans']].drop_duplicates()
#df_actores_cluster.to_csv('cluster_kmeans_df.csv',sep='|')
#df_actores_cluster = pd.read_csv('cluster_kmeans_df.csv',sep='|')


diccionario_actores = {}#diccionario_actores
for i in range(0,150):
    lista_actores_cluster = df_actores.FullName[df_actores.cluster_kmeans==i].unique()
    add_diccionario = {i:lista_actores_cluster}
    diccionario_actores.update(add_diccionario)
#import pickle
#with open('dict_actores_kmeans.pickle', 'wb') as handle:
#    pickle.dump(diccionario_actores, handle, protocol=pickle.HIGHEST_PROTOCOL)

df_actores_cluster = df_actores[['Title','cluster_kmeans']]
df_actores_cluster.to_csv('df_actores_cluster.csv',sep='|')
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ## IMPORTAR DATASET

# %%
df_actores_cluster = pd.read_csv('df_actores_cluster.csv',sep='|').iloc[:,1:]

# %% [markdown]
# ## PREDECIR ACTORES OPTIMOS

# %%
import pandas as pd
import numpy as np
import pandas_profiling 
import seaborn as sns
import matplotlib.pyplot as plt
from string import ascii_letters
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score, classification_report, confusion_matrix,accuracy_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.cluster import DBSCAN
from sklearn.decomposition import PCA
import unidecode as uni
import time
import pickle
pd.set_option('display.max_columns', None)
#with open('dict_actores.pickle', 'rb') as handle:
#    dict_actores = pickle.load(handle)
with open('dict_actores_kmeans.pickle', 'rb') as handle:
    dict_actores_kmeans = pickle.load(handle)

# %%
data = pd.read_csv('data_movies_final.csv',sep='|').iloc[:,1:]
data['Rate'][data.Rate>10] = data.Rate[data.Rate>10]*0.10
data['fecha_mes'] = data['fecha'][data.fecha.notnull()]
dummies_meses = pd.get_dummies(data.fecha_mes[data.fecha_mes.notnull()].str.split(pat='-').apply(lambda x: x[1])).rename(columns={'01':'ENERO','02':'FEBRERO','03':'MARZO','04':'ABRIL','05':'MAYO','06':'JUNIO','07':'JULIO','08':'AGOSTO','09':'SEPTIEMBRE','10':'OCTUBRE','11':'NOVIEMBRE','12':'DICIEMBRE'})
data = pd.concat([data,dummies_meses],axis=1)
data = data[data.fecha_mes.notnull()]
data = data.drop(['IDDataLens','cant_baja_votos','cant_media_votos','cant_alta_votos','fecha_mes'],axis=1)
fecha_anio = data.fecha[data.fecha.notnull()].str.split(pat='-').apply(lambda x: x[0]).astype(int)
data = data.drop(['fecha','largo_letras_titulo','popularity'],axis=1)
df_rate = pd.DataFrame(data.groupby(['Title'])['Rate'].mean()).reset_index()
data = data.merge(df_rate,how='left',left_on='Title',right_on='Title')
data = data.drop(['Rate_x'],axis=1)
data = data.iloc[:,:24]
data['fecha_anio'] = fecha_anio
dummies_anio = pd.get_dummies(pd.qcut(data.fecha_anio[data.fecha_anio.notnull()].astype(int),3,labels=['antiguos','modenos','actuales']))
data = pd.concat([data,dummies_anio],axis=1).drop(['fecha_anio'],axis=1)
df_actores_cluster = df_actores_cluster.drop_duplicates()
data = data.merge(df_actores_cluster,how='left',left_on='Title',right_on='Title')
data = data[data.cluster_kmeans.notnull()]
data_apropiado = pd.read_csv('data_apropiado.csv',sep='|').iloc[:,1:]
data_apropiado = data_apropiado.drop_duplicates()
data = data.merge(data_apropiado,how='left',left_on='Title',right_on='Title')
data = data.drop(['Title'],axis=1)
df = data.dropna()
df = data.drop_duplicates()
df = df.dropna()
df = df.drop_duplicates()
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
#              Budget  RuntimeMinutes  Action  Adventure  Animation  Biography  \
# 4        30000000.0              98       0          0          0          0
# 5        30000000.0              98       0          0          0          0
# 6        30000000.0              98       0          0          0          0
# 7        30000000.0              98       0          0          0          0
# 32        2000000.0             104       0          0          0          0
# ...             ...             ...     ...        ...        ...        ...
# 518242   45000000.0              84       0          0          1          0
# 518243   45000000.0              84       0          0          1          0
# 518262  149000000.0              85       0          0          1          0
# 518263  149000000.0              85       0          0          1          0
# 518264  149000000.0              85       0          0          1          0
#
#         Comedy  Crime  Drama  Family  Fantasy  Film-Noir  History  Horror  \
# 4            0      0      0       0        0          0        0       0
# 5            0      0      0       0        0          0        0       0
# 6            0      0      0       0        0          0        0       0
# 7            0      0      0       0        0          0        0       0
# 32           0      0      0       0        0          0        0       0
# ...        ...    ...    ...     ...      ...        ...      ...     ...
# 518242       0      0      0       0        0          0        0       0
# 518243       0      0      0       0        0          0        0       0
# 518262       0      0      0       0        0          0        0       0
# 518263       0      0      0       0        0          0        0       0
# 518264       0      0      0       0        0          0        0       0
#
#         Music  Musical  Mystery  Romance  Sci-Fi  Sport  Thriller  War  \
# 4           0        0        0        0       0      0         0    0
# 5           0        0        0        0       0      0         0    0
# 6           0        0        0        0       0      0         0    0
# 7           0        0        0        0       0      0         0    0
# 32          0        0        0        0       0      0         0    0
# ...       ...      ...      ...      ...     ...    ...       ...  ...
# 518242      0        0        0        0       0      0         0    0
# 518243      0        0        0        0       0      0         0    0
# 518262      0        0        0        0       0      0         0    0
# 518263      0        0        0        0       0      0         0    0
# 518264      0        0        0        0       0      0         0    0
#
#         Western  antiguos  modenos  actuales  cluster_kmeans  apropiado
# 4             1       1.0      0.0       0.0            29.0          0
# 5             1       1.0      0.0       0.0             2.0          0
# 6             1       1.0      0.0       0.0            14.0          0
# 7             1       1.0      0.0       0.0            32.0          0
# 32            1       0.0      0.0       1.0            29.0          0
# ...         ...       ...      ...       ...             ...        ...
# 518242        0       1.0      0.0       0.0            13.0          0
# 518243        0       1.0      0.0       0.0            65.0          0
# 518262        0       1.0      0.0       0.0            15.0          1
# 518263        0       1.0      0.0       0.0            13.0          1
# 518264        0       1.0      0.0       0.0            65.0          1
#
# [63409 rows x 28 columns]

# %% [markdown]
# ## SEPARO X y

# %%
X = df.drop(['cluster_kmeans','Budget','RuntimeMinutes','apropiado'],axis=1)
y = df.cluster_kmeans

# %%
from xgboost.sklearn import XGBClassifier
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
XGBClassifier = XGBClassifier(max_depth=25,iterations=25,alpha=0,learning_rate=0.9)
modelo = XGBClassifier.fit(X_train,y_train)
predict = modelo.predict(X_test)
# Out:
# /opt/conda/lib/python3.6/site-packages/dask/dataframe/utils.py:13: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
print('accuracy: '+str(accuracy_score(y_test, predict, normalize=True)))
print('precision: '+str(precision_score(y_test,predict,average='macro')))
print('recall: '+str(recall_score(y_test,predict,average='macro')))        
print(classification_report(y_test,predict))
print('')
print(confusion_matrix(y_test,predict))
# Out:
# accuracy: 0.12611708482676223
# precision: 0.060738221930233746
# recall: 0.0912631002814891
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       706
#          1.0       0.14      0.01      0.01      1445
#          2.0       0.11      0.09      0.10       922
#          3.0       0.00      0.00      0.00       172
#          4.0       0.00      0.00      0.00       195
#          5.0       0.00      0.00      0.00       418
#          6.0       0.00      0.00      0.00       290
#          7.0       0.14      0.21      0.17        62
#          8.0       0.12      0.09      0.11       556
#          9.0       0.00      0.00      0.00        19
#         10.0       0.00      0.00      0.00        76
#         11.0       0.00      0.00      0.00        19
#         12.0       0.14      0.21      0.17       999
#         13.0       0.16      0.35      0.22      1033
#         14.0       0.00      0.00      0.00       158
#         15.0       0.00      0.00      0.00       754
#         17.0       0.11      0.31      0.16       346
#         18.0       0.08      0.04      0.05        56
#         19.0       0.12      0.11      0.12       619
#         20.0       0.00      0.00      0.00       381
#         21.0       0.16      0.23      0.19       285
#         22.0       0.00      0.00      0.00       143
#         23.0       0.00      0.00      0.00       345
#         24.0       0.00      0.00      0.00       371
#         25.0       0.00      0.00      0.00       118
#         26.0       0.20      0.30      0.24        66
#         27.0       0.00      0.00      0.00        31
#         28.0       0.12      0.24      0.16       394
#         29.0       0.00      0.00      0.00        31
#         30.0       0.04      0.03      0.04        64
#         31.0       0.11      0.17      0.14       622
#         32.0       0.12      0.32      0.17      1413
#         35.0       0.00      0.00      0.00       258
#         39.0       0.13      0.23      0.17       551
#         40.0       0.23      0.21      0.22        39
#         43.0       0.00      0.00      0.00        64
#         44.0       0.10      0.16      0.12        64
#         47.0       0.00      0.00      0.00        35
#         49.0       0.00      0.00      0.00       419
#         50.0       0.00      0.00      0.00       452
#         55.0       0.00      0.00      0.00       878
#         59.0       0.00      0.00      0.00        89
#         63.0       0.14      0.05      0.07       308
#         64.0       0.16      0.29      0.21       215
#         65.0       0.00      0.00      0.00       179
#         74.0       0.06      0.07      0.06       107
#         77.0       0.02      0.02      0.02        48
#         80.0       0.00      0.00      0.00       289
#         84.0       0.12      0.11      0.12        63
#         85.0       0.11      0.33      0.16       290
#         90.0       0.00      0.00      0.00        22
#         94.0       0.00      0.00      0.00       301
#         95.0       0.14      0.27      0.19       736
#        105.0       0.12      0.23      0.16        39
#        106.0       0.12      0.17      0.14       357
#        108.0       0.00      0.00      0.00       171
#        109.0       0.10      0.31      0.16       773
#        110.0       0.12      0.32      0.17       312
#        118.0       0.15      0.19      0.17        57
#        122.0       0.12      0.08      0.09       423
#        136.0       0.00      0.00      0.00       140
#        137.0       0.00      0.00      0.00        84
#        149.0       0.00      0.00      0.00        53
#
#     accuracy                           0.13     20925
#    macro avg       0.06      0.09      0.07     20925
# weighted avg       0.08      0.13      0.09     20925
#
#
# [[ 0  4 22 ...  0  0  0]
#  [ 0  9 37 ...  0  0  0]
#  [ 0  3 86 ...  0  0  0]
#  ...
#  [ 0  0  2 ...  0  0  0]
#  [ 0  3  2 ...  0  0  0]
#  [ 0  1  2 ...  0  0  0]]
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
mat = confusion_matrix(y_test,predict)
plt.figure(figsize=(40,35))
sns.heatmap(mat, square=True, annot=True, fmt='d')
plt.title('Modelo Clasificacion Actores')
plt.xlabel('Etiquetas predichas')
plt.ylabel('Etiquetas verdaderas')
# Out:
# Text(335.5, 0.5, 'Etiquetas verdaderas')

# %% [markdown]
# ## ANALISIS DE RESULTADOS

# %%
import lime
import lime.lime_tabular
df_new = X_test
df_array = df_new.sample(1)
import shap  
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
plt.figure(figsize=(40,35))
importances = modelo.feature_importances_
indices = np.argsort(importances)
features = X_train.columns
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %% [markdown]
# ## EXPLAINER

# %%
explainer = shap.TreeExplainer(XGBClassifier)
shap_values = explainer.shap_values(df_array)
# Out:
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.

# %%
for i, df in enumerate(modelo.predict_proba(df_array)[0]):
    if df==modelo.predict_proba(df_array)[0].max():
        index=i

# %%
df_array
# Out:
#         Action  Adventure  Animation  Biography  Comedy  Crime  Drama  Family  \
# 131424       0          0          0          0       0      0      1       0
#
#         Fantasy  Film-Noir  History  Horror  Music  Musical  Mystery  Romance  \
# 131424        0          0        0       0      0        0        0        0
#
#         Sci-Fi  Sport  Thriller  War  Western
# 131424       0      0         0    0        0

# %%
features = df_array.columns
shap.force_plot(explainer.expected_value[index], shap_values[index], df_array,feature_names=features,out_names=['Cluster ¨Predicho'],link='logit')
# Out:
# <div id='i42W1LUNJBGDYQLSNMHTC'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["Cluster \u00a8Predicho"], "baseValue": 1.8864123821258545, "outValue": 2.445533275604248, "link": "logit", "featureNames": ["Action", "Adventure", "Animation", "Biography", "Comedy", "Crime", "Drama", "Family", "Fantasy", "Film-Noir", "History", "Horror", "Music", "Musical", "Mystery", "Romance", "Sci-Fi", "Sport", "Thriller", "War", "Western"], "features": {"0": {"effect": 3.42844650731422e-05, "value": 0.0}, "1": {"effect": 0.005241669714450836, "value": 0.0}, "2": {"effect": 0.0067144776694476604, "value": 0.0}, "3": {"effect": -0.01214943453669548, "value": 0.0}, "4": {"effect": -0.0004847882955800742, "value": 0.0}, "5": {"effect": -0.01272906456142664, "value": 0.0}, "6": {"effect": 0.6180379986763, "value": 1.0}, "7": {"effect": 0.0009566514636389911, "value": 0.0}, "8": {"effect": 0.0031630888115614653, "value": 0.0}, "9": {"effect": -0.0016652692575007677, "value": 0.0}, "10": {"effect": -0.007271080743521452, "value": 0.0}, "11": {"effect": 0.00373764312826097, "value": 0.0}, "12": {"effect": -0.004013539291918278, "value": 0.0}, "13": {"effect": -0.0005345249664969742, "value": 0.0}, "14": {"effect": -0.005930653773248196, "value": 0.0}, "15": {"effect": -0.02011839486658573, "value": 0.0}, "16": {"effect": 0.00624076509848237, "value": 0.0}, "17": {"effect": -0.0046076239086687565, "value": 0.0}, "18": {"effect": -0.008555704727768898, "value": 0.0}, "19": {"effect": -0.005441511981189251, "value": 0.0}, "20": {"effect": -0.00150406698230654, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i42W1LUNJBGDYQLSNMHTC')
#   );
# </script>

# %%
explainer = shap.TreeExplainer(modelo)
shap_values = explainer.shap_values(X_test.sample(500))
# Out:
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.

# %%
shap.summary_plot(shap_values[index], X_test.sample(500), plot_type="bar",color='black')

# %%
shap.summary_plot(shap_values, X_test.sample(1000))

# %% [markdown]
# ## RECOMENDACIONES DE ACTORES

# %%
X_test
# Out:
#              Budget  RuntimeMinutes  Action  Adventure  Animation  Biography  \
# 43999    40000000.0             149       0          0          0          0
# 134204  170000000.0             125       0          0          0          0
# 90735    25000000.0             106       1          0          0          0
# 121785   10000000.0              82       0          0          0          0
# 110886   75000000.0              99       0          0          0          0
# ...             ...             ...     ...        ...        ...        ...
# 74931    25000000.0             110       0          0          0          0
# 100085    3000000.0             101       0          0          0          0
# 12500     1000000.0              90       0          1          0          0
# 128617   45000000.0              93       0          0          0          0
# 26367    26000000.0              97       0          0          0          0
#
#         Comedy  Crime  Drama  Family  Fantasy  Film-Noir  History  Horror  \
# 43999        0      0      1       0        0          0        0       0
# 134204       0      0      0       0        0          0        0       0
# 90735        0      0      0       0        0          0        0       0
# 121785       0      0      0       0        0          0        0       0
# 110886       0      0      0       0        0          0        0       1
# ...        ...    ...    ...     ...      ...        ...      ...     ...
# 74931        0      1      0       0        0          0        0       0
# 100085       0      0      0       0        0          0        0       0
# 12500        0      0      0       0        0          0        0       0
# 128617       0      0      0       1        0          0        0       0
# 26367        1      0      0       0        0          0        0       0
#
#         Music  Musical  Mystery  Romance  Sci-Fi  Sport  Thriller  War  \
# 43999       0        0        0        0       0      0         0    0
# 134204      0        0        0        0       1      0         0    0
# 90735       0        0        0        0       0      0         0    0
# 121785      0        0        0        0       0      0         1    0
# 110886      0        0        0        0       0      0         0    0
# ...       ...      ...      ...      ...     ...    ...       ...  ...
# 74931       0        0        0        0       0      0         0    0
# 100085      0        0        1        0       0      0         0    0
# 12500       0        0        0        0       0      0         0    0
# 128617      0        0        0        0       0      0         0    0
# 26367       0        0        0        0       0      0         0    0
#
#         Western  apropiado
# 43999         0          0
# 134204        0          1
# 90735         0          0
# 121785        0          0
# 110886        0          1
# ...         ...        ...
# 74931         0          0
# 100085        0          0
# 12500         0          0
# 128617        0          1
# 26367         0          1
#
# [4696 rows x 24 columns]

# %%
predecir_actores = X_test[X_test.Adventure==1].sample(1)

# %%
predecir_actores
# Out:
#        Action  Adventure  Animation  Biography  Comedy  Crime  Drama  Family  \
# 16278       0          1          0          0       0      0      0       0
#
#        Fantasy  Film-Noir  History  Horror  Music  Musical  Mystery  Romance  \
# 16278        0          0        0       0      0        0        0        0
#
#        Sci-Fi  Sport  Thriller  War  Western
# 16278       0      0         0    0        0

# %%
modelo.predict(predecir_actores)[0]
# Out:
# 1.0

# %%
dict_actores_kmeans[modelo.predict(predecir_actores)[0]]
# Out:
# array(['Ian McShane', 'Geoffrey Rush'], dtype=object)

# %%
dict_actores_kmeans
# Out:
# {0: array(['Jennifer Aniston', 'Gerard Butler', 'Danny Huston',
#         'Geoffrey Rush', 'Dong-Gun Jang', 'Katharine Hepburn',
#         'Lloyd Bridges', 'Burt Lancaster', 'Jon Voight', 'Danny DeVito',
#         'Matt Damon', 'Claire Danes', 'Sam Worthington', 'Jamie Bell',
#         'Elizabeth Banks', 'Gary Sinise', 'Ben Affleck', 'James Frain',
#         'Charlize Theron', 'Kirsten Dunst', 'Gregory Smith', 'Jay Mohr',
#         'David Cross', 'John Malkovich', 'Rowan Atkinson', 'Stephen Rea',
#         'Justin Chambers', 'Mena Suvari', 'Jim Carrey', 'Jeff Daniels',
#         'Laurie Holden', 'Nicolas Cage', 'Ron Perlman', 'Claire Foy',
#         'Anne Bancroft', 'Val Kilmer', 'Freddie Prinze Jr.',
#         'Gerardo Taracena', 'Richard Gere', 'Christopher Eccleston',
#         'Hilary Swank', 'Ewan McGregor', 'Marília Pêra', 'Camila Amado',
#         'Kyle MacLachlan', 'Virginia Madsen', 'Madeleine Stowe',
#         'Daniel Day-Lewis', 'Eric Schweig', 'Joe Don Baker',
#         'Timothy Dalton', 'Jeroen Krabbé', 'Mary Steenburgen',
#         'Christopher Lloyd', 'Michael J. Fox', 'Lea Thompson',
#         'Alan Arkin', 'Billy Campbell', 'Wesley Snipes', 'Maury Chaykin',
#         'Sarah Jessica Parker', 'Brendan Fraser', 'Jessica Alba',
#         'Rob Corddry', 'Tommy Lee Jones', 'Michelle Yeoh', 'Max von Sydow',
#         'Tom Hanks', 'Sandra Bullock', 'Louis Gossett Jr.', 'Dennis Quaid',
#         'Meryl Streep', 'Bill Murray', 'George Clooney', 'Michael York',
#         'Marlon Brando', 'Fairuza Balk', 'David Thewlis', 'Rick Moranis',
#         'Robert Oliveri', 'Tony Ka Fai Leung', 'Qi Shu', 'Daniel Wu',
#         'Angelababy', 'Jet Li', 'Tony Chiu-Wai Leung', 'Dustin Hoffman',
#         'Geena Davis', 'Joan Cusack', 'Andy Garcia', 'Shammi Kapoor',
#         'Jackie Shroff', 'Anoop Menon', 'Kôichi Satô', 'Takuya Kimura',
#         'Takako Matsu', 'Haruka Ayase', 'Jessica Hester Hsuan',
#         'Jason Alexander', 'Bruce Willis', 'Elijah Wood',
#         'Julia Louis-Dreyfus', 'Anders Baasmo Christiansen',
#         'Kyrre Hellum', 'Elisabeth Moss', 'Rose Byrne', 'Jonah Hill',
#         'Laurence Fishburne', 'Adrien Brody', 'Topher Grace',
#         'Alice Braga', 'Sean Connery', 'José Wilker', 'Lorraine Bracco',
#         'Rupert Graves', 'Rufus Sewell', 'Tom Selleck', 'Bruce Greenwood',
#         'Paul Walker', 'Jason Biggs', 'Moon Bloodgood',
#         'Isabella Rossellini', 'Craig T. Nelson', 'Amelia Shankley',
#         'Lainie Kazan', 'Henry Cavill', 'Lukas Haas', 'Gary Oldman',
#         'Billy Burke', 'Amanda Seyfried', 'Kyeong-yeong Lee', 'Ye-jin Son',
#         'Hae-jin Yoo', 'Nam-gil Kim', 'Walter Matthau', 'John C. Reilly',
#         'Salma Hayek', 'Josh Hutcherson', 'Margherita Buy', 'Danny Kaye',
#         'Sandy Duncan', 'Jon Heder', 'Shirley MacLaine',
#         'Libuse Safránková', 'Rene Auberjonois',
#         'Christopher Daniel Barnes', 'David Carradine', 'Mako',
#         'Gene Hackman', 'Owen Wilson', 'Charles Malik Whitfield',
#         'Chris Mulkey', 'David Morrissey', 'Emily Watson',
#         'Virginie Ledoyen', 'Leonardo DiCaprio', 'Eddie Murphy',
#         'David Alan Grier', 'Robin Givens', 'Halle Berry', 'Julia Roberts',
#         'Goldie Hawn', 'Amy Schumer', 'Kim Coates', 'Kevin James',
#         'Jackie Chan', 'Claire Forlani', 'Tom Sizemore', 'Stanley Tucci',
#         'Tim Allen', 'Peter Falk', 'Charles Durning', 'Sacha Baron Cohen',
#         'Gustaf Hammarsten', 'Drew Barrymore', 'Ben Stiller',
#         'Harvey Fierstein', 'Cameron Diaz', 'Matthew Morrison',
#         'Steve Martin', 'Bonnie Hunt', 'Piper Perabo', 'Hilary Duff',
#         'Clifton Webb', 'Edward Herrmann', 'John Larroquette',
#         'Christine Ebersole', 'Barbra Streisand', 'Seth Rogen', 'Ice Cube',
#         'Benjamin Bratt', 'Kevin Hart', 'Tika Sumpter', 'Julie Andrews',
#         'Hector Elizondo', 'Anne Hathaway', 'Ginnifer Goodwin',
#         'Morgan Lily', 'Sam Neill', 'Chevy Chase', 'Daryl Hannah',
#         'Michael McKean', 'Will Ferrell', 'Amy Poehler',
#         'Jason Mantzoukas', 'Ryan Simpkins', 'Valeria Bruni Tedeschi',
#         'Robert De Niro', 'Sylvester Stallone', 'Kim Basinger',
#         'Gregory Hines', 'Denzel Washington', 'Whitney Houston',
#         'Courtney B. Vance', 'Jason Bateman', 'Charlie Day',
#         'Nikolaj Coster-Waldau', 'Jill Eikenberry', 'Farrah Fawcett',
#         'George Wendt', 'Jonathan Taylor Thomas', 'Cedric the Entertainer',
#         'Christina Milian', 'Kelli Garner', 'Paul Rudd', 'Rashida Jones',
#         'Miles Teller', 'Hugh Dancy', 'Isla Fisher', 'Krysten Ritter',
#         'Adam Sandler', 'Kevin Nealon', 'Wendi McLendon-Covey',
#         'Natasha Henstridge', 'Matthew Perry', 'Amanda Peet',
#         'Christopher Walken', 'Vince Vaughn', 'Rachel McAdams',
#         'Gwyneth Paltrow', 'Jack Black', 'Diane Keaton', 'Harrison Ford',
#         'Nina Foch', 'Brie Larson', 'Channing Tatum', 'John Cleese',
#         'Michael Clarke Duncan', 'Angelina Jolie', 'Tony Shalhoub',
#         'Christian Kane', 'Ryan Reynolds', 'Stephen Lang', 'Ralph Bellamy',
#         'Dan Aykroyd', 'John Leguizamo', 'Katherine Heigl',
#         'Daniel Sunjata', "Jason O'Mara", 'Madonna', 'Martin Henderson',
#         'Zach Galifianakis', 'Gal Gadot', 'Jon Hamm', 'Helen Mirren',
#         'Jennifer Garner', 'Ann Dowd', 'Danny Pino', 'James Spader',
#         'Jimmy Bennett', 'Jake Short', 'George Segal', 'James Caan',
#         'Bette Midler', 'Keanu Reeves', 'Jason Isaacs', 'Josh Peck',
#         'Nate Hartley', 'Kerry Washington', 'Clark Duke', 'Ed Begley Jr.',
#         'James Remar', 'Martin Lawrence', 'Nia Long', 'Zachary Levi',
#         'Patrick Dempsey', 'Kadeem Hardison', 'Kevin McKidd',
#         'Michelle Monaghan', 'Ellie Kemper', 'T.I.', 'Alison Brie',
#         'Laurence Olivier', 'Frank Langella', 'Kate Nelligan',
#         'Jack Palance', 'Simon Ward', 'David Suchet', 'Dan Stevens',
#         'Jennifer Ehle', 'Dakota Johnson', 'Jamie Dornan', 'Jack Thompson',
#         'Antonio Banderas', 'Thomas Jane', 'Ann Jillian',
#         'Robert Desiderio', 'Tomas Milian', 'Robert Redford', 'Lena Olin',
#         'Edward Norton', 'Paul Giamatti', 'Jessica Biel', 'Rosario Dawson',
#         'Taye Diggs', 'Amy Adams', 'Chris Messina', 'Lesley Ann Warren',
#         'Rubén Blades', 'Christopher Plummer', 'Ebon Moss-Bachrach',
#         'John Krasinski', "Vincent D'Onofrio", 'Helen Hunt',
#         'Kevin Spacey', 'Haley Joel Osment', 'Melissa Leo',
#         'Joseph Gordon-Levitt', 'Shailene Woodley', 'Zachary Quinto',
#         'Jimmy Smits', 'Holliston Coleman', 'Alan Alda', 'Mark Rylance',
#         'Amy Ryan', 'Winona Ryder', 'Brittany Murphy', 'Clea DuVall',
#         'Clint Eastwood', 'Dylan McDermott', 'Darrin Dewitt Henson',
#         'Samuel L. Jackson', 'Matthew McConaughey', 'Dane DeHaan',
#         'Jack Lemmon', 'Kevin Costner', 'Sean Penn', 'Javier Bardem',
#         'Jasmine Trinca', 'Idris Elba', 'Jack Nicholson', 'Kevin Bacon',
#         'Demi Moore', 'Tom Cruise', 'Frances McDormand', 'Eliza Dushku',
#         'James Franco', 'Johnny Depp', 'Helena Bonham Carter',
#         'Tracey Ullman', 'Mark Wahlberg', 'Ben Foster', 'Taylor Kitsch',
#         'Tom Berenger', 'Sharon Stone', 'William Baldwin', 'Polly Walker',
#         'Ben Kingsley', 'Josh Hartnett', 'Michiel Huisman', 'Hugh Jackman',
#         'Michael Caine', 'Christian Bale', 'Scarlett Johansson',
#         'Andrew Garfield', 'Ramya Krishnan', 'Sathyaraj', 'Prabhas',
#         'Rana Daggubati', 'David Caruso', 'Hal Holbrook',
#         'Jeanne Tripplehorn', 'Bradley Cooper', 'Jennifer Lawrence',
#         'Michael Vartan', 'Jordi Mollà', 'Zoe Saldana', 'Juliette Lewis',
#         'Ralph Fiennes', 'Angela Bassett', 'Benicio Del Toro',
#         'Demián Bichir', 'Rodrigo Santoro', 'Catalina Sandino Moreno',
#         'Clifton Powell', 'Jamie Foxx', 'Regina King', 'Ed Harris',
#         'Tilda Swinton', 'Chris Evans', 'Taraji P. Henson',
#         'Ralph Macchio', 'Justin Timberlake', 'Mark Strong',
#         'Joel Edgerton', 'Chris Pratt', 'Jessica Chastain',
#         'Garrett Hedlund', 'Mason Lee', 'Jude Law', 'Cate Blanchett',
#         'Mekhi Phifer', 'Eminem', 'Timothy Hutton', 'John Turturro',
#         'Maria Bello', 'Andrew Scott', 'Daniel Radcliffe', 'James McAvoy',
#         'John Barrymore', 'Marisa Tomei', 'William H. Macy',
#         'Ryan Phillippe', 'Anthony Quinn', 'Julianne Moore',
#         'Dominic West', 'Vincent Piazza', 'Morgan Freeman', 'Ashley Judd',
#         'Jim Caviezel', 'Adam Scott', 'Adewale Akinnuoye-Agbaje',
#         'Joy Bryant', 'Omar Benson Miller', 'Forest Whitaker',
#         'Matthew Fox', 'Ian McShane', 'Riccardo Scamarcio', 'Ruby Rose',
#         'Naomie Harris', 'Joon Lee', 'Tom Skerritt', 'Kate Beckinsale',
#         'Columbus Short', 'Keenan Wynn', 'Charles Bronson',
#         'Jan-Michael Vincent', 'Donald Sutherland', 'Stephen Dorff',
#         'Natascha McElhone', 'Martin Sheen', 'Michael Jai White',
#         'Robert Downey Jr.', 'Charles S. Dutton', 'Penélope Cruz',
#         "Frances O'Connor", 'Vera Farmiga', 'Patrick Wilson',
#         'Joaquin Phoenix', 'James Gandolfini', 'Peter Stormare',
#         'Courteney Cox', 'David Arquette', 'Neve Campbell', 'Lucy Hale',
#         'Diane Cilento', 'Christopher Lee', 'Edward Woodward',
#         'Ellen Burstyn', 'Leelee Sobieski', 'Kate Beahan',
#         'Liev Schreiber', 'Chad Michael Murray', 'Paris Hilton',
#         'Vincent Price', 'Frank Lovejoy', 'Phyllis Kirk', 'Carolyn Jones'],
#        dtype=object),
#  1: array(['Ian McShane', 'Geoffrey Rush'], dtype=object),
#  2: array(['Ian McShane', 'Geoffrey Rush'], dtype=object),
#  3: array(['Robert Englund'], dtype=object),
#  4: array(['Christopher Lee', 'Alan Arkin', 'Bill Hunter'], dtype=object),
#  5: array(['Johnny Depp', 'Penélope Cruz'], dtype=object),
#  6: array(['Paresh Rawal', 'Kay Kay Menon'], dtype=object),
#  7: array(['Ethan Hawke', 'Denzel Washington', "Vincent D'Onofrio",
#         'Chris Pratt', 'Charles Bronson', 'Eli Wallach', 'John Leguizamo',
#         'Denis Leary', 'Ray Romano', 'Kate Winslet', 'Shailene Woodley',
#         'Theo James', 'Ian Holm', 'Gary Oldman', 'Bruce Willis',
#         'Milla Jovovich', 'Carol Burnett', 'Jim Carrey', 'Will Arnett',
#         'Steve Carell', 'Ron Perlman', 'Selma Blair', 'Doug Jones',
#         'Matt Damon', 'Monica Bellucci', 'Heath Ledger',
#         'Arnold Schwarzenegger', 'Art Carney', 'F. Murray Abraham',
#         'Charles Dance', 'Scott Weinger', 'Willem Dafoe',
#         'Ellen DeGeneres', 'Alexander Gould', 'Woody Harrelson',
#         'Mark Ruffalo', 'Ian McKellen', 'Viggo Mortensen', 'Elijah Wood',
#         'Orlando Bloom', 'David Strathairn', 'Mary-Louise Parker',
#         'Sarah Bolger', 'Freddie Highmore', 'Christopher Walken',
#         'Rosario Dawson', 'Dwayne Johnson', 'Eddie Murphy',
#         'Miguel Ferrer', 'Ming-Na Wen', 'BD Wong', 'Julia Roberts',
#         'Nathan Lane', 'Armie Hammer', 'Rade Serbedzija', 'Peter Firth',
#         'Bill Paxton', 'Charlize Theron', 'Gary Sinise', 'Martin Lawrence',
#         'Debra Messing', 'Ashton Kutcher', 'Peter Fonda', 'Richard Lynch',
#         'Nathan Fillion', 'Logan Lerman', 'Brandon T. Jackson',
#         'Tommy Lee Jones', 'Will Smith', 'Don Cheadle',
#         'Robert Downey Jr.', 'Jude Law', 'Mark Strong', 'Rachel McAdams',
#         'John Barrymore', 'Stephen Lang', 'Jason Momoa', 'Max von Sydow',
#         'James Earl Jones', 'Donnie Yen', 'Vin Diesel', 'Deepika Padukone',
#         'Bill Murray', 'Drew Barrymore', 'Cameron Diaz', 'Lucy Liu',
#         'John Hurt', 'Ian McShane', 'Joseph Fiennes', 'James Woods',
#         'Tate Donovan', 'Josh Keaton', 'Sean Bean', 'Helen Hunt',
#         'Tom Hanks', 'Jami Gertz', 'Cary Elwes', 'Harry Dean Stanton',
#         'Dylan McDermott', 'Sarah Michelle Gellar', 'Freddie Prinze Jr.',
#         'Linda Cardellini', 'Mickey Rooney', 'James Cromwell',
#         'Magda Szubanski', 'Joan Cusack', 'Kelsey Grammer', 'Tim Allen',
#         'Gabriele Ferzetti', 'Anthony Hopkins', 'Ray Liotta',
#         'Julianne Moore', 'Sam Neill', 'William H. Macy', 'Téa Leoni',
#         'Alessandro Nivola', 'Robert Patrick', 'Ryan Reynolds',
#         'Vera Farmiga', 'Hector Elizondo', 'Patrick Stewart',
#         'Kimberly Williams-Paisley', 'Ólafur Darri Ólafsson',
#         'Tia Carrere', 'Luke Perry', 'Javier Gurruchaga', 'Gabino Diego',
#         'Neus Asensi', 'James Spader', 'Angela Bassett', 'Peter Facinelli',
#         'Robin Tunney', 'Sylvester Stallone', 'Jet Li', 'Antonio Banderas',
#         'Samuel L. Jackson', 'Jamie Bell', 'Rachel Bilson', 'George Lopez',
#         'Anne Hathaway', 'Gérard Depardieu', 'Glenn Close',
#         'Ioan Gruffudd', 'Adam Sandler', 'Peter Dinklage',
#         'Michelle Monaghan', 'Kevin James', 'Terence Stamp',
#         'Jennifer Tilly', 'Warren Beatty', 'Goldie Hawn', 'Diane Keaton',
#         'Nastassja Kinski', 'Larry Miller', 'John Turturro',
#         'Emmanuelle Chriqui', 'Nick Swardson', 'Fay Bainter', 'Danny Kaye',
#         'Oprah Winfrey', 'Steve Buscemi', 'Dakota Fanning',
#         'Debbie Reynolds', 'Henry Gibson', 'Jane Krakowski',
#         'Kristen Johnston', 'Helen Mirren', 'John Malkovich',
#         'Bette Midler', 'Nicole Kidman', 'Matthew Broderick',
#         'Paula Prentiss', 'Harvey Keitel', 'Patricia Arquette',
#         'Dan Aykroyd', 'Jessica Biel', 'Shirley MacLaine', 'Michael Caine',
#         'Will Ferrell', 'Shia LaBeouf', 'Zooey Deschanel', 'Jon Heder',
#         'Susan Sarandon', 'Patrick Dempsey', 'James Marsden', 'Amy Adams',
#         'Robert De Niro', 'Jackie Chan', 'Chris Tucker', 'Andy Samberg',
#         'Selena Gomez', 'Billy Crystal', 'Robin Williams',
#         'Julia Louis-Dreyfus', 'Alan Cumming', 'Traylor Howard',
#         'Jamie Kennedy', 'Brad Pitt', 'Marion Cotillard', 'Jared Harris',
#         'Claire Forlani', 'Jake Weber', 'Michelle Yeoh', 'Ken Watanabe',
#         'Annabella Sciorra', 'Cuba Gooding Jr.', 'Christopher Plummer',
#         'Al Pacino', 'Diane Venora', 'Burt Reynolds', 'Til Schweiger',
#         'Chris Cooper', 'Tobey Maguire', 'Elizabeth Banks', 'James Franco',
#         'Andy Serkis', 'Gaby Hoffmann', 'Anne Heche', 'Anna Magnani',
#         'Geraldine Brooks', 'Rossano Brazzi', 'Heiner Lauterbach',
#         'Matthias Koeberlin', 'Christopher Atkins', 'Michael Leon',
#         'Edward Asner', 'Mary Tyler Moore', 'Mel Gibson', 'David Paymer',
#         'Maria Bello', 'Elias Koteas', 'Francesca Neri', 'Tom Sizemore',
#         'Ewan McGregor', 'Josh Hartnett', 'Stellan Skarsgård',
#         'Daniel Craig', 'Lena Endre', 'Michael Nyqvist', 'Noomi Rapace',
#         'Harrison Ford', 'Rubén Blades', 'Margaret Colin',
#         'Renée Zellweger', 'Paul Giamatti', 'Jack Nicholson',
#         'Leonardo DiCaprio', 'Mark Wahlberg', 'Wendy Crewson',
#         'Tom Skerritt', 'Jodie Foster', 'Matthew McConaughey',
#         'Gordon Pinsent', 'Christian Slater', 'Stephen Rea',
#         'Molly Parker', 'Ryan Phillippe', 'Joseph Cross', 'Barry Pepper',
#         'George Clooney', 'Gene Hackman', 'Jon Voight', 'Lisa Bonet',
#         'Jürgen Prochnow', 'Armand Assante', 'Rob Schneider',
#         'Paul Walker', 'Jordana Brewster', 'Michelle Rodriguez',
#         'Forest Whitaker', 'Marton Csokas', 'Robert Redford',
#         'Catherine McCormack', 'Stephen Dillane', 'Nicolas Cage',
#         'Giovanni Ribisi', 'Angelina Jolie', 'Zachery Ty Bryan',
#         'Lucas Black', 'Sebastian Koch', 'Mary Elizabeth Winstead'],
#        dtype=object),
#  8: array([], dtype=object),
#  9: array([], dtype=object),
#  10: array(['John Hurt', 'Diane Lane', 'Ellen Barkin', 'Will Poulter',
#         'Iwan Rheon', 'Keenan Wynn', 'Brian Keith', 'Tim Matheson',
#         'Tony Barry', 'Henry Thomas', 'Rachel Friend', 'Raymond Burr',
#         'Aamir Khan', 'Donna Murphy', 'Karoline Herfurth',
#         'Rachel McAdams', 'Noomi Rapace', 'Barbara Hershey',
#         'Claudia Karvan', 'Emily Woof', 'Richard Roxburgh',
#         'F. Murray Abraham', 'Ralph Fiennes', 'Adrien Brody',
#         'Mathieu Amalric', 'John Wayne', 'Charlie Sheen',
#         'Kiefer Sutherland', 'Oliver Platt', "Chris O'Donnell",
#         'Richard Chamberlain', 'Michael York', 'Gino Cervi',
#         'Milla Jovovich', 'Matthew Macfadyen', 'Logan Lerman',
#         'Van Heflin', 'Gene Kelly', 'Gloria Stuart', 'Aleksey Makarov',
#         'Yuriy Chursin', 'Jeffrey Tambor', 'Tom Kenny', 'Sean Connery',
#         'Sam Neill', 'Alec Baldwin', 'Jim Carrey', 'Nancy Kovack',
#         'Til Schweiger', 'Natalia Avelon', 'Bruce Greenwood',
#         'David Spade', 'Frankie Muniz', 'Don Rickles', 'Tom Hanks',
#         'Tim Allen', 'Rhys Wakefield', 'Gary Oldman', 'Carla Gugino',
#         'Britt Robertson', 'Christopher Plummer', 'Heath Ledger',
#         'Andrew Garfield', 'Tchéky Karyo', 'Freddie Prinze Jr.',
#         'Roger Moore', 'Christopher Walken', 'Tanya Roberts',
#         'Grace Jones', 'Elijah Wood', 'Vanessa Redgrave',
#         'Gael García Bernal', 'Amanda Seyfried', 'Michael Ironside',
#         'Virginia Madsen', 'Christopher Lambert', 'Helena Bonham Carter',
#         'Peter Kay', 'Ed Harris', 'Colin Farrell', 'Jim Sturgess',
#         'Steve Buscemi', 'Steve Carell', 'Mason Cook', 'Sienna Miller',
#         'Charlie Hunnam', 'Robert Pattinson', 'Tom Holland', 'Luke Wilson',
#         'Dax Shepard', 'Maya Rudolph', 'Terry Crews', 'John Goodman',
#         'Jim Broadbent', 'Celia Imrie', 'Christopher Eccleston',
#         'Robert Sheehan', 'Sharon Horgan', 'Judith Anderson',
#         'Eddie Albert', 'Beatrice Straight', 'Dennis Hopper',
#         'Keanu Reeves', 'Joe Morton', 'Sandra Bullock', 'James Stewart',
#         'Urmila Matondkar', 'Kevin Spacey', 'Jennifer Garner',
#         'Cheryl Hines', 'William Christian', 'Paris Hilton', 'John Cleese',
#         'Morris Chestnut', 'Piper Perabo', 'Eddie Cibrian',
#         'Leslie Nielsen', 'James Remar', 'Arnold Schwarzenegger',
#         'Peter Boyle', 'Linda Blair', 'Dustin Hoffman', 'Emma Thompson',
#         'Queen Latifah', 'Will Ferrell', 'Mackenzie Astin',
#         'Jake Gyllenhaal', 'Anne Hathaway', 'Judy Greer', 'Candice Bergen',
#         'Kate Hudson', 'Angelababy', 'Xiao Chen', 'Brittany Snow',
#         'Anna Kendrick', 'Rebel Wilson', 'Hailee Steinfeld',
#         'Tommy Lee Jones', 'Meryl Streep', 'Jean Smart',
#         'Mary Steenburgen', 'Colin Firth', 'Heather Graham',
#         'Minnie Driver', 'Paulina García', 'Marco Pérez', 'Cathy Moriarty',
#         'Sharon Stone', 'Jeremy Northam', 'John Astin', 'Trini Alvarado',
#         'Michael J. Fox', 'Bill Murray', 'Matthew McConaughey',
#         'Dan Aykroyd', 'Sigourney Weaver', 'Drew Barrymore',
#         'Jimmy Fallon', 'Jason Spevack', 'Jack Kehler', 'Bruce Campbell',
#         'Vincent Pastore', 'Elizabeth Hurley', 'Matthew Perry',
#         'Noble Willingham', 'Bruce Willis', 'Damon Wayans',
#         'Mariel Hemingway', 'Monica Keena', 'Michael Keaton',
#         'Katie Holmes', 'Robert De Niro', 'Michelle Pfeiffer',
#         'Stefania Sandrelli', 'Amy Poehler', 'Tina Fey',
#         'Oksana Akinshina', 'Stephen Rea', 'Chloë Sevigny',
#         'Charles Durning', 'Margot Kidder', 'Alyson Hannigan',
#         'Jason Biggs', 'Gene Hackman', 'John Travolta', 'Danny DeVito',
#         'Michael Tucker', 'Gabrielle Anwar', 'Gig Young', 'Kirk Douglas',
#         'Thelma Ritter', 'Michael Chiklis', 'Sean Hayes', 'Jane Lynch',
#         'Chris Diamantopoulos', 'Simon Helberg', 'Kim Basinger',
#         'Gabriel Byrne', 'Brad Pitt', 'Jack Black', 'Iben Hjejle',
#         'Cameron Diaz', 'Nikolaj Coster-Waldau', 'Jill Eikenberry',
#         'Paul Newman', 'Jennifer Jason Leigh', 'Marcia Gay Harden',
#         'Maura Tierney', 'Ray Romano', 'Tracy Morgan', 'Kevin Dillon',
#         'Kevin Connolly', 'Adrian Grenier', 'Gary Cole', 'Adam LaVorgna',
#         'Jonathan Taylor Thomas', 'Jessica Biel', 'Linda Sorensen',
#         'Ann Jillian', 'Eva Marie Saint', 'Hal Holbrook', 'Jack Nicholson',
#         'Kathy Bates', 'Hope Davis', 'James Cromwell', 'Magda Szubanski',
#         'Miriam Margolyes', 'Jeanette Nolan', 'Fran Kranz',
#         'Chris Hemsworth', 'Kristen Connolly', 'Amanda Peet',
#         'Ashton Kutcher', 'Taryn Manning', 'Aimee Garcia',
#         'Peter Dinklage', 'Kristen Bell', 'Melissa McCarthy',
#         'Ella Anderson', 'Martin Lawrence', 'Nia Long', 'Paul Giamatti',
#         'Brian Kerwin', 'Katherine Heigl', 'James Marsden', 'David Morse',
#         'Doug Hutchison', 'Robert Pastorelli', 'Jamie Foxx',
#         'Victoria Smurfit', 'Anjelica Huston', 'Christopher Lloyd',
#         'Dan Hedaya', 'Jonathan Lipnicki', 'Brenda Song', 'Macha Grenon',
#         'Rosamund Pike', 'Patrick Dempsey', 'Reese Witherspoon',
#         'Josh Lucas', 'Yaphet Kotto', 'Charles Grodin', 'Sophie Marceau',
#         'David Paymer', 'Ben Whishaw', 'Elizabeth Perkins', 'Glenn Close',
#         'Joan Cusack', 'Hayden Panettiere', 'Billy Bob Thornton',
#         'Greg Kinnear', 'Mickey Rourke', 'Jean-Claude Van Damme',
#         'Ted Danson', 'Saul Rubinek', 'Glenne Headly', 'Anthony Hopkins',
#         'Aidan Quinn', 'Julia Ormond', 'Brenda Blethyn', 'Keira Knightley',
#         'James McAvoy', 'Saoirse Ronan', 'Jessica Lange', 'Channing Tatum',
#         'Misel Maticevic', 'Frank Langella', 'Tim Roth', 'Nicole Kidman',
#         'James Garner', 'Gena Rowlands', 'Ryan Gosling', 'Alyson Stoner',
#         'Laurence Olivier', 'Jennifer Jones', 'Patricia Clarkson',
#         'Rena Sofer', 'Julianne Moore', 'Portia Doubleday',
#         'Chloë Grace Moretz', 'Piper Laurie', 'Sissy Spacek', 'Amy Irving',
#         'Hilary Swank', 'Lisa Kudrow', 'Gerard Butler', 'Josh Hartnett',
#         'Rose Byrne', 'Diane Kruger', 'Robert Redford', 'Morgan Freeman',
#         'Jennifer Lopez', 'Omar Sharif', 'Gabrielle Union',
#         'Michelle Monaghan', 'Max von Sydow', 'Chiara Caselli',
#         'Gary Sinise', 'Michael Caine', 'Rade Serbedzija',
#         'Brendan Fraser', 'Cliff Robertson', 'Jack Thompson',
#         'Jennifer Grey', 'David Duchovny', 'Gillian Anderson',
#         'Cate Blanchett', 'Vic Morrow', 'Alan Alda', 'Billy Dee Williams',
#         'Bruce Dern', 'Stellan Skarsgård', 'Leelee Sobieski',
#         'Sam Shepard', 'Mary-Louise Parker', 'Casey Affleck',
#         'Mark Strong', 'Tom Hardy', 'James Rebhorn', 'Jeff Daniels',
#         'Kate Winslet', 'Michael Fassbender', 'Seth Rogen',
#         'Samuel L. Jackson', 'Elizabeth Olsen', 'Dae-han Ji',
#         'James Woods', 'Treat Williams', 'Elizabeth McGovern',
#         'Danny Huston', 'Jon Voight', 'Don Cheadle', 'Ving Rhames',
#         'Andy Garcia', 'Laurence Fishburne', 'Vanessa Williams',
#         'Willem Dafoe', 'Madonna', 'Joe Mantegna', 'Daniel Craig',
#         'Kathleen Wilhoite', 'Clark Gregg', 'Thomas Kretschmann',
#         'Powers Boothe', 'Will Patton', 'Denzel Washington', 'Ryan Hurst',
#         'Wood Harris', 'Catherine Zeta-Jones', 'Jude Law', 'Noah Emmerich',
#         'Edward Norton', 'Geoffrey Rush', 'Joseph Fiennes',
#         'Warren Beatty', 'Harvey Keitel', 'Ben Kingsley', 'Annette Bening',
#         'Lucas Black', 'Ray Winstone', 'John Malkovich', 'Lena Headey',
#         'Dougray Scott', "Robert Ri'chard", 'Al Pacino', 'Sean Penn',
#         'Penelope Ann Miller', 'John Leguizamo', 'Ethan Hawke',
#         'Maria Bello', 'Rachael Leigh Cook', 'Ryan Phillippe',
#         'Claire Forlani', 'Antonio Banderas', 'Alfre Woodard',
#         'Renée Zellweger', 'Ewan McGregor', 'Emily Watson',
#         'Barbara Flynn', 'Kevin Bacon', 'Stuart Townsend',
#         'Charlize Theron', 'Callum Keith Rennie', 'Suki Kaiser',
#         'Lloyd Bridges', 'Kathleen Quinlan', 'Rajkummar Rao',
#         'Forest Whitaker', 'Liam Neeson', 'Elizabeth Banks',
#         'Ben McKenzie', 'Richard Gere', 'John Mahoney', 'Laura Linney',
#         'Maia Morgenstern', 'Monica Bellucci', 'Jim Caviezel',
#         'David Thewlis', 'John C. Reilly', 'Ariel Gade', 'Joe Pantoliano',
#         'January Jones', 'Benicio Del Toro', 'Emily Blunt', 'Jon Bernthal',
#         'Oscar Isaac', 'John Lithgow', 'Richard Dreyfuss',
#         'Linda Hamilton', 'J.T. Walsh', 'Billy Crawford', 'Tuva Novotny',
#         'Michael Angarano', 'Milo Ventimiglia', 'Dominik García-Lorido',
#         'Jin-young Jung', 'Ju-bong Gi', 'Shôichi Ozawa', 'Etsuko Ichihara',
#         'Michael Douglas', 'Bradford Dillman', 'Jan-Michael Vincent',
#         'Edgar Ramírez', 'Olivia Munn', 'L. Scott Caldwell',
#         'Dwayne Johnson', 'Kathy Baker', 'Michael Shannon',
#         'Michael Rooker', 'Kenneth Tsang', 'Mira Sorvino',
#         'Robert Knepper', 'Ben Affleck', 'Anthony Mackie',
#         'Gemma Arterton', 'Justin Timberlake', 'Eddie Marsan',
#         'Robert Englund', 'Rodrigo Santoro', 'Esai Morales',
#         'Madeleine Stowe', 'Ray Liotta', 'Giancarlo Giannini',
#         'Jonathan Pryce', 'Patricia Arquette', 'Ben Foster',
#         'Melissa George', 'Justin Long', 'Ruth Livier', 'Nathalie Boltt'],
#        dtype=object),
#  11: array(['Roddy McDowall', 'José Ferrer', 'Charles Nelson Reilly',
#         'Bob Hoskins', 'Mark Gatiss', 'Matt Lucas', 'Tyne Daly'],
#        dtype=object),
#  12: array([], dtype=object),
#  13: array([], dtype=object),
#  14: array([], dtype=object),
#  15: array(['Julie Walters', 'Emma Thompson', 'Kelly Macdonald',
#         'Fred Willard', 'Jeff Garlin', 'Nicole Kidman', 'Daniel Craig',
#         'Harrison Ford', 'Cate Blanchett', 'Shia LaBeouf',
#         'Eddie Redmayne', 'John C. Reilly', 'Samuel L. Jackson',
#         'Brie Larson', 'Tom Hiddleston', 'Nicholas Hoult', 'James McAvoy',
#         'Michael Fassbender', 'Jennifer Lawrence', 'Angelina Jolie',
#         'Elle Fanning', 'Lesley Manville', 'Rinko Kikuchi',
#         'Charlie Hunnam', 'Idris Elba', 'Charlie Day', 'Tilda Swinton',
#         'Christoph Waltz', 'Alexander Skarsgård', 'Michael Caine',
#         'Christian Bale', 'Heath Ledger', 'Tom Cruise', 'Bill Paxton',
#         'Brendan Gleeson', 'Emily Blunt'], dtype=object),
#  16: array(['Elizabeth Taylor', 'Rock Hudson', 'James Dean', 'Mads Mikkelsen',
#         'Mandy Moore', 'Claire Holt', 'Frank Sinatra', 'Lara Jill Miller',
#         'Lee Marvin', 'Charles Bronson', 'Ernest Borgnine',
#         'John Cassavetes', 'Sean Connery', 'Alberto Sordi', 'Sarah Miles',
#         'Amitabh Bachchan', 'Irrfan Khan', 'Deepika Padukone', 'Om Puri',
#         'Lara Dutta', 'Jean Simmons', 'Marlon Brando', 'Paul Newman',
#         'Robert Redford', 'Charles Durning', 'Fabrizio Bentivoglio',
#         'Lunetta Savino', 'Frank Lammers', 'Kirk Douglas', 'Dennis Farina',
#         'Woody Harrelson', 'David Cross', 'Cheryl Hines', 'Meret Becker',
#         'Samantha Morton', 'Colin Farrell', 'Jessica Chastain',
#         'Maria Doyle Kennedy', 'Peter Mullan', 'Ben Cross', 'Ethan Hawke',
#         'Noah Taylor', 'Sarah Snook', 'Madeleine West', 'Oriol Pla',
#         'Naveen Andrews', 'Eva Amurri Martino', 'Til Schweiger',
#         'William H. Macy', 'Thomas Kretschmann', 'Clark Gregg',
#         'Edward James Olmos', 'Jimmy Smits', 'Esai Morales',
#         'Hrithik Roshan', 'Rohit Roy', 'Ronit Roy', 'Farhan Akhtar',
#         'Joss Ackland', 'Greta Scacchi', 'Charles Dance', 'Don Gordon',
#         'Robert Vaughn', 'Jacqueline Bisset', 'Mickey Rourke',
#         'Anthony Michael Hall', 'Danny Trejo', 'Malcolm McDowell',
#         'Stacy Keach', 'Chris Haywood'], dtype=object),
#  17: array([], dtype=object),
#  18: array(['Robert Montgomery', 'Greta Garbo'], dtype=object),
#  19: array(['Charles Boyer', 'Marlene Dietrich', 'Basil Rathbone',
#         'Frank Finlay', 'Richard Roundtree', 'R.H. Thomson',
#         'William Baldwin', 'Bruce Ramsay', 'Barbara Barrie',
#         'Jackie Earle Haley', 'Dennis Quaid', 'Paul Dooley', 'Irene Dunne',
#         'Joseph Schildkraut', 'Howard Keel', 'Florian Lukas',
#         'Nora Tschirner', 'Anneke Kim Sarnau', 'Christian Ulmen',
#         'Taneli Mäkelä', 'Petteri Summanen', 'Humphrey Bogart',
#         'William Holden', 'Walter Hampden', 'Harrison Ford',
#         'Nancy Marchand', 'Julia Ormond', 'Greg Kinnear', 'Aamir Khan',
#         'Patrick Stewart', 'Sasson Gabai', 'Moni Moshonov', 'Red Skelton',
#         'Esther Williams', 'Shelley Duvall', 'Keith Carradine',
#         'Ray Milland', "Ryan O'Neal", 'Ali MacGraw', 'John Marley',
#         'Judith Anderson', 'Amrita Puri', 'Manish Chaudhary',
#         'James Brolin', 'Thomas Jane', 'Samantha Morton', 'Beau Bridges',
#         "Matt O'Leary", 'Jamie Chung', 'James Remar', 'Eileen Walsh',
#         'Karl Shiels', 'Pauline Etienne', 'Lauren Lee Smith',
#         'Eric Balfour', 'Mayko Nguyen', 'Andrew Lincoln',
#         'Lionel Barrymore', 'Greer Garson', 'Gregory Peck', 'Jerzy Trela',
#         'Agata Kulesza', 'Peter Vaughan', 'Dustin Hoffman', 'James Woods',
#         'James Marsden', 'Alexander Skarsgård', 'Jason Robards',
#         'George Segal', 'Clint Ritchie', 'Malcolm McDowell',
#         'Fedor Bondarchuk', 'Aleksey Serebryakov', 'Martin Gabel',
#         'Sean Connery', 'Elliott Gould', 'Paolo Bonacelli',
#         'Steven Williams', 'Lou Diamond Phillips', 'Eric Roberts',
#         'Jaime King', 'Jensen Ackles'], dtype=object),
#  20: array(['Tom Hanks', 'Michael Jeter', 'T.J. Miller', 'Jamie Chung',
#         'Ryan Potter', 'John C. Reilly', 'Sarah Silverman', 'Jane Lynch',
#         'Jack McBrayer', 'Matthew McConaughey', 'Anne Hathaway',
#         'Jessica Chastain', 'Mackenzie Foy', 'Jeff Goldblum',
#         'Bill Pullman', 'Liam Hemsworth', 'Gerard Butler',
#         'Christopher Mintz-Plasse', 'Eddie Murphy', 'Antonio Banderas',
#         'Cameron Diaz', 'Chiwetel Ejiofor', 'Rachel McAdams',
#         'Benedict Cumberbatch', 'Benedict Wong',
#         'Kevin Michael Richardson', 'Bryce Johnson', 'Harrison Ford',
#         'Daniel Craig', 'Olivia Wilde', 'Abigail Spencer'], dtype=object),
#  21: array(['James McAvoy', 'Rebecca Hall', 'Michael Sheen', 'Mark Gatiss',
#         'Steve Pemberton'], dtype=object),
#  22: array(['Johnny Depp', 'Geoffrey Rush', 'Orlando Bloom', 'Keira Knightley'],
#        dtype=object),
#  23: array([], dtype=object),
#  24: array(['Sophie Marceau', 'David Spade', 'Natasha Henstridge',
#         'Angus Macfadyen'], dtype=object),
#  25: array(['Gig Young', 'Harry Morgan', 'Jean Hagen', 'Polly Bergen',
#         'Claudia Christian', 'Marc Alaimo', 'Samuel L. Jackson',
#         'David Carradine', 'Stacy Keach', 'Keith Carradine',
#         'Dennis Quaid', 'Woody Harrelson', 'Alice Braga', 'Emory Cohen',
#         'Liam Hemsworth', 'Wei Zhao', 'Tim Roth', 'Danila Kozlovsky',
#         'Tara Strong', 'Richard Burton', 'Roger Moore', 'Hardy Krüger',
#         'Richard Harris', 'Michael Douglas', 'Danny DeVito',
#         'Kathleen Turner', 'Brian Kerwin', 'Linda Hamilton',
#         'Dick Van Dyke', 'Robert Redford', 'Bryce Dallas Howard',
#         'Mickey Rooney', 'José Mota', 'Michelle Jenner', 'Michael Paré',
#         'Brendan Fletcher', 'Willam Belli', 'Andy Garcia', 'Maria Bello',
#         'Christopher Lee', 'Keanu Reeves', 'David Andrews', 'Sean Connery',
#         'Tetsurô Tanba', 'Antonio Banderas', 'Mark Valley',
#         'Michael Angarano', 'Jemaine Clement', 'Bruce Willis',
#         'Johnathon Schaech', 'Thomas Jane', 'Darren McGavin', 'Ned Beatty',
#         'Robin Mattson', 'Arnold Schwarzenegger', 'Dan Hedaya',
#         'Chris Cooper', 'Naomi Watts', 'Jake Gyllenhaal', 'Don Johnson',
#         'Stephen Dorff', 'Christina Ricci', 'Nick Swardson', 'Paul Rudd',
#         'Zooey Deschanel', 'Elizabeth Banks', 'Jessica Lange',
#         'Bill Murray', 'Sharon Stone', 'Julie Delpy', 'Sacha Baron Cohen',
#         'Gustaf Hammarsten', 'Joss Ackland', 'Cathy Podewell',
#         'Linnea Quigley', 'Tchéky Karyo', 'Brenda Blethyn',
#         'Martin Clunes', 'Fernando Rey', 'Giancarlo Giannini',
#         'David Ogden Stiers', 'Nathan Lane', 'Kelsey Grammer',
#         'Clark Gable', 'Doris Day', 'Jsu Garcia', 'Ben Stiller',
#         'Amanda Seyfried', 'Adam Driver', 'Jeff Goldblum', 'Jim Carrey',
#         'Geena Davis', 'Damon Wayans', 'Divya Dutta', 'Irrfan Khan',
#         'Paul Walker', 'Rachael Leigh Cook', 'Freddie Prinze Jr.',
#         'Nicolas Cage', 'Laura Dern', 'Willem Dafoe', 'Tom Skerritt',
#         'Summer Glau', 'Adam Sandler', 'Bradley Whitford',
#         'Maureen Stapleton', 'Shelley Long', 'Tom Hanks', 'Joanna Cassidy',
#         'Christina Applegate', 'Josh Charles', 'Nick Nolte',
#         'Catherine Keener', 'Shirley MacLaine', 'Christopher Plummer',
#         'Marcia Gay Harden', 'Wendell Pierce', 'China Zorrilla',
#         'José Ángel Egido', 'Blanca Portillo', 'Madonna',
#         'Bruce Greenwood', 'Randy Quaid', 'Bernadette Peters',
#         'Glenn Close', 'Julianne Moore', "Chris O'Donnell", 'Liv Tyler',
#         'Silvio Orlando', 'Claudia Gerini', 'Priyanka Chopra',
#         'Kiron Kher', 'Eugene Levy', 'Helen Mirren', 'Julie Walters',
#         'Penelope Wilton', 'Maggie Smith', 'Judi Dench', 'Bill Nighy',
#         'Dev Patel', 'Michelle Pfeiffer', 'Alec Baldwin', 'Kareena Kapoor',
#         'Ashley Johnson', 'Andrew Lawrence', "Rickey D'Shon Collins",
#         'Ellen Barkin', 'Kirsten Dunst', 'Denise Richards',
#         'Allison Janney', 'Glória Pires', 'Ângelo Paes Leme',
#         'Emilio Dantas', 'Sally Kellerman', 'Peter Outerbridge', 'Julissa',
#         'Ernesto Gómez Cruz', 'Matt Dillon', 'Ralph Macchio',
#         'Patrick Swayze', 'Gemma Arterton', 'Cillian Murphy',
#         'Brie Larson', 'Armie Hammer', 'Ambra Angiolini', 'Charles Dance',
#         'Kerry Fox', 'Robert Carlyle', 'David Ngoombujarra', 'Ron Silver',
#         'Gina Gershon', 'Lukas Haas', 'Madeline Zima', 'James Brolin',
#         'Ving Rhames', 'Jeremy Piven', 'Tom Wilkinson', 'Ben Foster',
#         'Penelope Ann Miller', 'Luke Wilson', 'Michael Ironside',
#         'Bill Paxton', 'David Warner', 'Steve Martin', 'Josh Hutcherson',
#         'Dolph Lundgren', 'Corey Sevier', 'Zelda Williams', 'Meryl Streep',
#         'Lily Tomlin', 'John C. Reilly', 'Anne Bancroft', 'Ellen Burstyn',
#         'Winona Ryder', 'Val Kilmer', 'Ryan Phillippe', 'Will Forte',
#         'Kristen Wiig', 'Jude Law', 'Natalie Portman', 'Dan Aykroyd',
#         'Terry Kinney', 'Gillian Anderson', 'Rachael Blake',
#         'Emily Browning', 'Ewen Leslie', 'Morgan Fairchild',
#         'Verna Felton', 'Demián Bichir', 'Joaquín Cosio', 'Leïla Bekhti',
#         'Ana de la Reguera', 'Anika Noni Rose', 'Nick Robinson',
#         'Amandla Stenberg', 'Miranda Richardson', 'Emmy Rossum',
#         'Gerard Butler', 'Patrick Wilson', 'Maximilian Schell',
#         'Michael York', 'Jane Seymour', 'Darin De Paul', 'Robert Englund',
#         'Lon Chaney', 'Asia Argento', 'Katrina Kaif', 'Chico Díaz',
#         'Maitê Proença', 'Diogo Morgado', 'Natalie Dormer',
#         'Angus Macfadyen', 'Tonantzin Carmelo', 'Barnard Hughes',
#         'Joel Grey', 'Ewan McGregor', 'Matthew Macfadyen',
#         'Michelle Williams', 'François Cluzet', 'Om Puri', 'Xueqi Wang',
#         'You Ge', 'Bingbing Fan', 'Xiaoming Huang', 'Rupert Graves',
#         'Bokeem Woodbine', 'Diane Farr', 'Sissy Spacek',
#         'Richard Farnsworth', 'Nicole Kidman', 'Hugo Weaving',
#         'Joseph Fiennes', 'Lisa Flanagan', 'Mädchen Amick',
#         'Dana Ashbrook', 'Bette Davis', 'John Wayne', 'Henry Fonda',
#         'Demi Moore', 'David Duchovny', 'Benjamin Hollingsworth',
#         "Mo'Nique", 'Gabourey Sidibe', 'Billy Bob Thornton',
#         'Paul Giamatti', 'Zac Efron', 'Tom Welling', 'Terence Stamp',
#         'Peter Fonda', 'Lesley Ann Warren', 'Luis Guzmán',
#         'Nastassja Kinski', 'Kristen Stewart', 'Dakota Fanning',
#         'Michael Shannon', 'Timothy Spall', 'Andrew Scott',
#         'Burt Lancaster', 'Dean Martin', 'Jessica Tandy', 'Lynn Redgrave',
#         'Ian McKellen', 'Lolita Davidovich', 'Brendan Fraser',
#         'James Franco', 'Peter Sarsgaard', 'Jean-Claude Van Damme',
#         'Rachel Griffiths', 'William Sadler', 'Jason Bateman',
#         'Hope Davis', 'Jonah Bobo', 'Haley Ramm', 'Saoirse Ronan',
#         'Clive Owen', 'Jason Clarke', 'Steven Cree Molison',
#         'Arjun Rampal', 'Michael Keaton', 'Deborah Kara Unger',
#         'Brian Cox', 'John Slattery', 'John Malkovich', 'Rosario Dawson',
#         'America Ferrera', 'Michael Peña', 'Sarah Silverman',
#         'Joe Mantegna', 'William H. Macy', 'Frances Bay', 'Julia Stiles',
#         'Matthew McConaughey', 'Thomas Haden Church', 'William Devane',
#         'Christian Kane', 'Henning Jensen', 'Karen-Lise Mynster',
#         'Charlotte Bradley', 'Dara Devaney', 'Giovanni Ribisi',
#         'Cate Blanchett', 'Katie Holmes', 'Clifton Collins Jr.',
#         'Colin Farrell', 'James Spader', 'Holly Hunter', 'Elias Koteas',
#         'Don Cheadle', 'Sandra Bullock', 'Thandie Newton',
#         'William Shatner', 'Adrienne Barbeau', 'Dennis Hopper',
#         'Diane Lane', 'Mickey Rourke', 'Morris Chestnut', 'Romany Malco',
#         'Regina Hall', 'Michael Kenneth Williams', 'Richard Masur',
#         'Ted Danson', 'Rachel Ticotin', 'Colm Meaney', 'Jimmy Smits',
#         'Jon Seda', 'Maria del Mar', 'Powers Boothe', 'Mako',
#         'Oliver Platt', 'Henry Ian Cusick', 'Keith David', 'Larenz Tate',
#         'Freddy Rodríguez', 'Chris Tucker', 'Christoph Waltz',
#         'Danny Huston', 'Amy Adams', 'Krysten Ritter', 'Elisabeth Moss',
#         'Albert Dupontel', 'Pam Grier', 'Rutger Hauer', 'Eric Roberts',
#         'Ray Liotta', 'Mekhi Phifer', 'LL Cool J', 'Jolene Blalock',
#         'Sam Shepard', 'Diane Kruger', 'Benicio Del Toro',
#         'Mathieu Amalric', 'Gina McKee', 'Isabelle Huppert',
#         'Charles Berling', 'Laura Harring', 'Yancey Arias',
#         'Alexa PenaVega', 'Colin Firth', 'Patricia Clarkson',
#         'Orlando Bloom', 'Ian Holm', 'Ralph Fiennes', 'Penélope Cruz',
#         'Anthony Michael Hall', 'Nicole de Boer', 'Christopher Walken',
#         'Omar Sharif', "Peter O'Toole", 'Charlie Hunnam', 'Olivia Wilde',
#         'Giovanna Ralli', 'Michael Caine', 'Vladek Sheybal',
#         'Helen Shaver', 'Tsuyoshi Ihara', 'David Morse', 'Rainn Wilson',
#         'Jared Breeze', 'Lauren Cohan', 'Jim Norton', 'Piper Perabo',
#         'Brooklynn Proulx', 'Lance Henriksen', 'Renée Elise Goldsberry',
#         'Stephen Rea', 'Derek Jacobi', 'Adrien Brody', 'Jordana Brewster',
#         'Marthe Keller', 'Eric Mabius', 'Adrian Grenier', 'Stephen Lang',
#         'Dylan Minnette', 'Daniel Zovatto', 'Danny Trejo',
#         'Christian Slater', 'Michael T. Weiss', 'Clifton Powell',
#         'Robert Wisden', 'Sean Bean', 'Neal McDonough', 'Sophia Bush',
#         'Jennifer Jason Leigh', 'Kevin Bacon', 'Djimon Hounsou',
#         'Donald Faison', 'Brittany Daniel', 'Eric Balfour', 'Ray Winstone',
#         'Ron Perlman', 'Cuba Gooding Jr.', 'Taryn Manning',
#         'James Marsden', 'Tygo Gernandt', 'Dan Stevens',
#         'Bérénice Marlohe', 'Liam Cunningham', 'Danielle Panabaker',
#         'Tobin Bell', 'James Ransone', 'Caroline Dhavernas',
#         'Chris Messina', 'Sarah Michelle Gellar', 'Clea DuVall',
#         'Jason Behr', 'Melissa George', 'Josh Duhamel', 'Louis Ferreira',
#         'John Leguizamo', 'Jacob Latimore', 'Will Patton',
#         'Milla Jovovich', 'Hakeem Kae-Kazim', 'Jessica Biel', 'Sam Neill',
#         'Billy Zane', 'Bruno Campos', 'Will Estes', 'Vic Morrow',
#         'Doug McGrath', 'Jeff Fahey', 'Pierce Brosnan', 'Rider Strong',
#         'Mischa Barton', 'Cameron Bright'], dtype=object),
#  26: array(['Charles Laughton'], dtype=object),
#  27: array(['Michel Muller', 'Ryôko Hirosue', 'Robert Joy', 'Sherry Miller',
#         'Kevin Zegers', 'James Caan', 'Sally Kellerman', 'Peter Boyle',
#         'Kevin Pollak', 'Miguel A. Núñez Jr.', 'Vivica A. Fox',
#         'Pam Grier', 'Rutger Hauer', 'Eric Roberts', 'Ray Liotta',
#         'Mekhi Phifer', 'LL Cool J', 'Jolene Blalock', 'John Malkovich',
#         'Evangeline Lilly', 'Aidan Gillen', 'Paddy Considine'],
#        dtype=object),
#  28: array(['Ian McShane', 'Geoffrey Rush'], dtype=object),
#  29: array(['Burl Ives', 'Julie Harris', 'James Dean'], dtype=object),
#  30: array(['Tommy Lee Jones', 'Evan Rachel Wood', 'Cate Blanchett',
#         'Jenna Boyd', 'Shiang-chyi Chen', 'Adam Sandler', 'Terry Crews',
#         'Taylor Lautner', 'Jorge Garcia', 'Tom Cruise', 'Robert Knepper',
#         'Aldis Hodge', 'James Franco', 'LeVar Burton', 'Patrick Stewart',
#         'Brent Spiner', 'Michelle Pfeiffer', 'Brad Pitt',
#         'Catherine Zeta-Jones', 'Joseph Fiennes', 'Dustin Hoffman',
#         'Matthew Broderick', 'Tracey Ullman', 'Emma Watson', 'Sean Bean',
#         'Pierce Brosnan', 'Famke Janssen', 'Charles Dance',
#         'Brendan Fraser', 'Andy Serkis', 'Rosamund Pike', 'Dwayne Johnson',
#         'Luke Wilson', 'Eddie Izzard', 'J.K. Simmons', 'Lewis Black',
#         'Bruce Greenwood', 'Hilary Swank', 'Delroy Lindo', 'Will Ferrell',
#         'Will Arnett', 'Elizabeth Banks', 'Chris Pratt',
#         'Robert Downey Jr.', 'Chris Evans', 'Jeremy Renner',
#         'Scarlett Johansson', 'Sean Connery', 'Uma Thurman',
#         'Ralph Fiennes', 'Deborah Kerr', 'Ron Perlman', 'Ray Liotta',
#         'Leelee Sobieski', 'Willem Dafoe', 'Ice Cube', 'Samuel L. Jackson',
#         'Scott Speedman', 'Rainn Wilson', 'Demi Lovato', 'Jack McBrayer',
#         'Oliver Platt', 'Jack Black', 'Michael Cera', 'Olivia Wilde',
#         'John Leguizamo', 'Denis Leary', 'Ray Romano', 'John Lithgow',
#         'Eddie Murphy', 'Cameron Diaz', 'Nicole Kidman', 'Thomas Gibson',
#         'Woody Allen', 'Gene Hackman', 'Sylvester Stallone',
#         'Sharon Stone', 'Eugene Levy', 'Steve Martin', 'Bonnie Hunt',
#         'Hilary Duff', 'Gabrielle Union', 'Scott Caan',
#         'Michael Clarke Duncan', 'Matthew McConaughey', 'Charlize Theron',
#         'Art Parkinson', 'Ryan Reynolds', 'Morena Baccarin', 'T.J. Miller',
#         'Rita Hayworth', 'Robert Mitchum', 'Jack Lemmon', 'Stephen Lang',
#         'Marg Helgenberger', 'Dylan Minnette', 'Dennis Haysbert',
#         'Idris Elba', 'Christian Bale', 'Gerard Butler', 'Gerald McRaney',
#         'Cuba Gooding Jr.', 'David Oyelowo', 'Ben Kingsley',
#         'Jared Harris', 'Richard Ayoade', 'Robert Patrick',
#         'Zooey Deschanel', 'Josh Hutcherson', "Annette O'Toole",
#         'Robert Blake', 'Wesley Snipes', 'Woody Harrelson',
#         'Jennifer Lopez', 'Ben Stiller', 'Vince Vaughn', 'Owen Wilson',
#         'Katharine Hepburn', 'Warren Beatty', 'Annette Bening',
#         'Garry Shandling', 'Charles Boyer', 'Irene Dunne',
#         'Maria Ouspenskaya', 'Humphrey Bogart', 'Anjelica Huston',
#         'Jeff Garlin', 'Jeff Goldblum', 'Alec Baldwin',
#         'Elizabeth Perkins', 'Tobey Maguire', 'Jamie Lee Curtis',
#         'Dan Aykroyd', 'Tim Allen', 'Frank Langella',
#         'Arnold Schwarzenegger', 'Danny DeVito', 'Emma Thompson',
#         'Linda Singer', 'Jeremy Ratchford', 'Kieran Culkin',
#         'Mary Elizabeth Winstead', 'Anna Kendrick', 'Rose Byrne',
#         'Aasif Mandvi', 'Emory Cohen', 'Kathleen Turner',
#         'Jennifer Aniston', 'Eric Dane', 'Reese Witherspoon',
#         'Donal Logue', 'Mark Ruffalo', 'Susan Sarandon', 'Renée Taylor',
#         'Jude Law', 'Sienna Miller', 'Shelley Winters', 'Michael Caine',
#         'John Goodman', 'Greg Kinnear', 'Nicolas Cage', 'Don Cheadle',
#         'Téa Leoni', 'Jeremy Piven', 'Jason Lee', 'David Cross',
#         'Obba Babatundé', 'Martin Lawrence', 'Dane DeHaan',
#         'Robert Pattinson', 'Jake Gyllenhaal', 'Donald Sutherland',
#         'Mark Wahlberg', 'Edward Norton', 'Jim Carrey', 'Ed Harris',
#         'Laura Linney', 'Noah Emmerich', 'Cybill Shepherd',
#         'Charles Grodin', 'Jeannie Berlin', 'Jerry Stiller',
#         'Michelle Monaghan', 'Claudia Karvan', 'Alex Dimitriades',
#         'Iain Glen', 'Susan Lynch', 'Viola Davis', 'Robert De Niro',
#         'Billy Crystal', 'Lisa Kudrow', 'William Holden', 'Walter Hampden',
#         'Harrison Ford', 'Nancy Marchand', 'Julia Ormond', 'Salma Hayek',
#         'Tom Hanks', 'Stanley Tucci', 'Chi McBride', 'Anthony Quinn',
#         'Michael Parks', 'George Maharis', 'Johnny Depp',
#         'Gwyneth Paltrow', 'Ewan McGregor', 'Olivia Munn', 'Ray Barrett',
#         'Matt Damon', 'Kate Winslet', 'Bruce Boxleitner', 'Tom Wright',
#         'Lin Shaye', 'Robert Loggia', 'Kelly Preston', 'Phil Hartman',
#         'Rita Wilson', 'Sinbad', 'Clifton Powell', 'Thandie Newton',
#         'Helen Mirren', 'Morgan Freeman', 'Bruce Willis',
#         'Mary-Louise Parker', 'Brian Cox', 'Noel Fisher', 'Kyle Gallner',
#         'George Clooney', 'Billy Bob Thornton', 'Geoffrey Rush',
#         'Tom Wilkinson', 'Robert Carlyle', 'Paul Bettany', 'Maggie Q',
#         'Richard Jenkins', 'Julia Roberts', 'Javier Bardem',
#         'Robert Redford', 'Stockard Channing', 'Joe Mantegna',
#         'Timothy Spall', 'Kirsten Dunst', 'Jim Sturgess', 'David Morse',
#         'Richard Gere', 'Lonette McKee', 'Diane Lane', 'Gregory Hines',
#         'Ben Affleck', 'Rachel McAdams', 'John Travolta', 'James Cromwell',
#         'Timothy Hutton', 'Madeleine Stowe', 'Catherine Keener',
#         'Jamie Foxx', 'Tom Hollander', 'Teri Hatcher', 'Jennifer Saunders',
#         'Dakota Fanning', 'Miko Hughes', 'Valerie Mahaffey',
#         'Bradley Cooper', 'Guy Pearce', 'Ingrid Bergman', 'José Ferrer',
#         'Michael Douglas', 'David Suchet', 'Viggo Mortensen',
#         'Christopher Plummer', 'Ron Rifkin', 'Kevin Costner', 'Joe Morton',
#         'Susanna Thompson', 'Beau Bridges', 'Maria Bonnevie', 'Kim Bodnia',
#         'Colin Farrell', 'Robert Duvall', 'Randy Quaid', 'Sidney Poitier',
#         'Diane Venora', 'Dylan Baker', 'Monica Potter',
#         'Suzanne Pleshette', 'Burt Reynolds', 'Howard Hesseman',
#         'Peter MacNicol', 'Joaquin Phoenix', 'Edgar Ramírez',
#         'Jennifer Lawrence', 'Sean Penn', 'Giovanni Ribisi',
#         'Ryan Gosling', 'Emma Stone', 'Al Pacino', 'Carla Gugino',
#         'Jaime King', 'Nana Visitor', 'Bumper Robinson', 'Joe Pantoliano',
#         'Kim Basinger', 'Kiefer Sutherland', 'Eva Longoria',
#         'Martin Balsam', 'Chris Sarandon', 'Jacqueline McKenzie',
#         'Thomas Jane', 'Robert Sheehan', 'Clive Owen', 'Chris Cooper',
#         'Franka Potente', 'Angela Bassett', 'Michael C. Hall',
#         'Everett McGill', 'Katherine Heigl', 'Julianne Moore',
#         'Anne Heche', 'Janet Leigh', 'Anthony Perkins', 'James Whitmore',
#         'Linda Hunt', 'Penelope Ann Miller', 'Tom Sizemore',
#         'Kathleen Quinlan', 'Sam Neill', 'Laurence Fishburne',
#         'Joely Richardson'], dtype=object),
#  31: array(['Cynthia Stevenson', 'Frankie Muniz', 'Anthony Anderson',
#         'George Clooney', 'John Goodman', 'John Turturro',
#         'Tim Blake Nelson', 'Jonathan Banks', 'Paul Hogan', 'Elijah Wood',
#         'French Stewart', 'Paula Garcés', 'Andrey Smolyakov',
#         'Aleksey Chadov', 'Agniya Ditkovskite', 'Tyler James Williams',
#         'Robert Loggia', 'Kim Basinger', 'Alec Baldwin', 'Maggie Smith',
#         'Goldie Hawn', 'Diane Keaton', 'Bette Midler', 'Kathy Bates',
#         'Billy Bob Thornton', 'Christina Hendricks', 'Vince Vaughn',
#         'Chris Pratt', 'Vincent Price', 'Brendan Gleeson', 'Luke Evans',
#         'Kevin James', "Keir O'Donnell", 'Raini Rodriguez',
#         'Lloyd Bridges', 'Charlie Sheen', 'Valeria Golino', 'Cary Elwes',
#         'John Astin', 'Jodie Foster', 'Harold Gould', 'Jamie Lee Curtis',
#         'Mark Harmon', 'Lindsay Lohan', 'Cozi Zuehlsdorff', 'Shelley Long',
#         'Sandra Bernhard', 'Gaby Hoffmann', 'Shah Rukh Khan',
#         'Raveena Tandon', 'Bruce Willis', 'Catherine Zeta-Jones',
#         'Rebecca Hall', 'Jessica Biel', 'Leslie Nielsen',
#         'Jackie Earle Haley', 'Kate Winslet', 'Patrick Wilson',
#         'Donnie Wahlberg', 'Jordana Brewster', 'James Franco',
#         'Tyrese Gibson', 'James Marsden', 'Michelle Monaghan',
#         'Takuya Kimura', 'Yû Aoi', 'Rutger Hauer', 'Angus Macfadyen',
#         'Eddie Griffin', 'Nadia Bjorlin', 'Kevin Bacon',
#         'Kiefer Sutherland', 'Julia Roberts', 'William Baldwin',
#         'Ellen Page', 'Diego Luna', 'Nina Dobrev', 'James Norton',
#         'Sarah Polley', 'Adrien Brody', 'Kevin Costner', 'Kevin Kline',
#         'Danny Glover', 'Tom Hanks', 'Denzel Washington', 'Jack Nicholson',
#         'Michael Caine', 'Stephen Dorff', 'Jennifer Lopez',
#         'Nikolaj Lie Kaas', 'Sarah Juel Werner', 'Sam Shepard',
#         'Tobey Maguire', 'Natalie Portman', 'Jake Gyllenhaal',
#         'Jackie Shroff', 'Zhiwen Wang', 'Kari Heiskanen', 'Pertti Sveholm',
#         'Marlon Brando', 'E.G. Marshall', 'Jane Fonda', 'Robert Redford',
#         'Ho-jin Chun', 'Yun-shik Baek', 'Barry Corbin', 'Robert Beltran',
#         'Hideko Takamine', 'Takahiro Tamura', 'Seiji Miyaguchi',
#         'Robert Cummings', 'Guy Pearce', 'Jason Clarke', 'Shia LaBeouf',
#         'Tom Hardy', 'Ben Kingsley', 'Ryan Reynolds', 'Matthew Goode',
# ...
#         'Sissy Spacek', 'Simon Baker', 'Laurie Holden'], dtype=object),
#  187: array(['Karl Malden', 'Terence Stamp', 'Lara Dutta', 'Mikako Ichikawa',
#         'Manami Konishi', 'Rade Serbedzija', 'Peter Firth', 'Bill Paxton',
#         'Charlize Theron', 'Sylvia Syms', 'Anthony Quayle', 'Alan Alda',
#         'Ellen Burstyn', 'John Mills', 'Sophia Loren', 'Edward Woodward',
#         'Jack Thompson', 'John Waters', 'Bryan Brown', 'Dinah Shore'],
#        dtype=object),
#  188: array(['Woody Harrelson', 'Josh Hutcherson', 'Jennifer Lawrence',
#         'Liam Hemsworth', 'Kevin Bacon', 'James McAvoy',
#         'Michael Fassbender', 'Ben Foster', 'Dominic Cooper',
#         'Willem Dafoe', 'Jason Patric', 'Sandra Bullock', 'Ken Watanabe',
#         'Bryan Cranston', 'Elizabeth Olsen', 'Matthew Broderick',
#         'Hank Azaria', 'Raymond Burr', 'Eddie Murphy', 'Antonio Banderas',
#         'Cameron Diaz', 'Richard Dreyfuss', 'Josh Lucas', 'Emmy Rossum',
#         'Diane Venora', 'Dennis Storhøi', 'Estella Warren', 'Jean Marais',
#         'George C. Scott', 'André Dussollier', 'Vincent Cassel',
#         'Eduardo Noriega', 'Jana Brejchová', 'Emma Watson', 'Dan Stevens',
#         'Luke Evans', 'Josh Gad', 'Michael Pate', 'Paul Walker',
#         'Vin Diesel', 'Michelle Rodriguez', 'Dwayne Johnson'], dtype=object),
#  189: array([], dtype=object),
#  190: array(['David Carradine', 'Bruce Campbell', 'Paul Wesley',
#         'Donald Sutherland', 'Denzel Washington', 'John Goodman',
#         'Judy Garland', 'Lorne Greene', 'John Wayne', 'Lee Marvin',
#         'Jack Warden', 'Mickey Rooney', 'Teri Garr', 'José Sacristán',
#         'Susú Pecoraro', 'Juan Diego Botto', 'Peter Boyle', 'Gene Wilder',
#         'Madeline Kahn', 'Danila Kozlovsky', 'Nikita Panfilov',
#         'Howard Hesseman', 'Eric Brown', 'Jonas Bloquet', 'Vinnie Jones',
#         'Svetlana Khodchenkova', 'Anna Chipovskaya', 'John Belushi',
#         'Lon Chaney', 'Johnny Lever', 'Archana Puran Singh', 'Gene Kelly',
#         'Leslie Caron', 'Ethan Hawke', 'Julie Delpy', 'Charles Bronson',
#         'Radhika Apte', 'Shirley Knight', 'Ellen Page', 'Liev Schreiber',
#         'David Thewlis', 'Julia Stiles', 'Gregory Peck', 'Lee Remick',
#         'David Warner'], dtype=object),
#  191: array(['Sean Connery', 'Demián Bichir', 'Tony Revolori', 'Riz Ahmed',
#         'Matthew Broderick', 'Uma Thurman', 'Nathan Lane', 'Will Ferrell',
#         'Ginger Rogers', 'Fred Astaire', 'Jeffrey Combs', 'Ian Holm',
#         'Famke Janssen', 'Geert Van Rampelberg', 'Ina Geerts',
#         'Laura Verlinden', 'Claire Bloom', 'Cliff Robertson',
#         'Lilia Skala', 'Marlene Dietrich', 'Sam Jaffe', 'Humphrey Bogart',
#         'Ingrid Bergman', 'Liev Schreiber', 'Naomi Watts', 'Edward Norton',
#         'Greta Garbo', 'Lee J. Cobb', 'Richard Crenna',
#         'Edward G. Robinson', 'Barbara Stanwyck', 'Fred MacMurray',
#         'Edie Falco', 'Camilla Belle', 'Albert Finney', 'Harvey Keitel',
#         'Edward Fox', 'Keith Carradine', 'Patrick Wilson', 'Ellen Page',
#         'Sandra Oh', 'Kirk Douglas', 'Marlon Brando', 'Karl Malden',
#         'Rod Steiger', 'John Derek', 'Grayson Hall', 'David Selby',
#         'Kate Jackson', 'Ola Rapace', 'Negra Li', 'Joss Ackland',
#         'Sean Bean', 'Lara Flynn Boyle', 'Terence Knox', 'Paul Scherrer',
#         'Ryan Bollman', 'Christie Clark', 'Ted Levine', 'Alisha Newton',
#         'Kevin Zegers', 'Kaley Cuoco', 'Dana Andrews'], dtype=object),
#  192: array(['Zasu Pitts', 'John Wayne', 'Claire Trevor', 'John Carradine',
#         'Mike Connors', 'Red Buttons', 'Ann-Margret', 'Humphrey Bogart',
#         'Ida Lupino', 'Arthur Kennedy', 'Dominique Swain', 'John Cleese',
#         'John Rhys-Davies', 'Jeff Fahey', 'Peter Cushing', 'Mel Gibson',
#         'Hugh Keays-Byrne', 'Steve Bisley', 'Fedja van Huêt',
#         'Kiefer Sutherland', 'Kristy Swanson', 'Michael Paré',
#         'Bryan Brown', 'Daryl Hannah', 'Patrick Bauchau', 'Mads Ousdal',
#         'Henrik Mestad', 'Kyrre Hellum', 'Naseeruddin Shah', 'Jack Warden',
#         'Kate Jackson', 'Rue McClanahan', 'Cary Grant',
#         'Helena Bonham Carter', 'Amy Poehler', 'Tina Fey', 'Maya Rudolph',
#         'Oksana Akinshina', 'Stephen Rea', 'Chloë Sevigny',
#         'Charles Durning', 'Margot Kidder', 'Sihung Lung', 'Lai Wang',
#         'Pete Postlethwaite', 'Neil Morrissey', 'Bill MacDonald',
#         'Renée Zellweger', 'Matthew McConaughey', 'Tori Spelling',
#         'Jerzy Trela', 'Robert Wieckiewicz', 'Karolina Gruszka',
#         'Ginger Rogers', 'Fred Astaire', 'Bill Bixby', 'Jon Heder',
#         'Efren Ramirez', 'Glória Pires', 'Andrea Beltrão', 'Paloma Duarte',
#         'Lília Cabral', 'Paul Anthony Stewart', 'Ghita Nørby',
#         'Anthony Quinn', 'Gigi Proietti', 'Dominique Sanda',
#         'Jean Simmons', 'Katina Paxinou', 'Sô Yamamura', 'Seiji Miyaguchi',
#         'Keiko Kishi', 'Saul Rubinek', 'Joe Cobden', 'Jackie Cooper',
#         'Edward Asner', "Chris O'Donnell", 'Alberto Sordi',
#         'Nino Manfredi', 'Christa B. Allen', 'Pepe Soriano',
#         "Matt O'Leary", 'Deepak Dobriyal', 'Kangana Ranaut',
#         'Antonia Thomas', 'Peter Falk', 'Judge Reinhold',
#         'Laura San Giacomo', 'David Paymer', 'Melanie Mayron',
#         'Jeff Daniels', 'Michael Tucker', 'Holly Fields', 'Paul Soles',
#         'Andrew Chalmers', 'Don McKellar', 'Marya Delver', 'Piper Laurie',
#         'Pat Evison', 'Denise Nicholas', 'Hye-su Kim', 'Qi Shu',
#         'Wei Zhao', 'Mark Chao', 'Amber Kuo', 'Greta Garbo',
#         'Genevieve Buechner', 'Richard Harmon', 'Alan Rickman',
#         'Emma Thompson', 'Carla Gugino', 'Simon Baker', 'Kirk Cameron',
#         'Deborah Kerr', 'Jason Robards', 'John Hurt', 'Timothy Spall',
#         'Colm Meaney', 'Freddie Highmore', 'Mammootty', 'Tabu',
#         'Aishwarya Rai Bachchan', 'Sylvia Sidney', 'Beulah Bondi',
#         'Amitabh Bachchan', 'Om Puri', 'Preity Zinta', 'Hrithik Roshan',
#         'Barbara Hershey', 'David Carradine', 'George Sanders',
#         'Jennifer Jones', 'Charlton Heston', 'Tom Tully', 'Karl Malden',
#         'Lionel Barrymore', 'Christopher Cazenove', 'Anne Bancroft',
#         'Patty Duke', 'Inga Swenson', 'Diana Muldaur', 'Larry Gates',
#         'Donald Sutherland', 'Veronica Cartwright', 'Jeff Goldblum',
#         'Ger Ryan', 'David Wilmot', 'Carice van Houten', 'Paul Wesley',
#         'Anna Kendrick', 'Stanley Baker', 'Michael York', 'Michelle Ye',
#         'Alain Cuny', 'Daniel J. Travanti', 'Richard Masur',
#         'JoBeth Williams', 'Geraldine Fitzgerald', 'Rod Steiger',
#         'Brock Peters', 'Megan Mullally', 'Ray Winstone',
#         'David Threlfall', 'Tamlyn Tomita', 'Brett Cullen', 'Wes Studi',
#         'Carlos Bernard', 'Lesley Ann Warren', 'Janine Turner',
#         'Isaiah Washington', "Mo'Nique", 'Eric Roberts',
#         'Urmila Matondkar', 'Jean-Philippe Écoffey', 'Susan Lynch',
#         'Eric van der Donk', 'Tommy Lee Jones', 'Robert De Niro',
#         'Harvey Keitel', 'David Proval', 'Mickey Rooney', 'Aaron Paul',
#         'Mary Elizabeth Winstead', 'Nick Offerman', 'Monica Keena',
#         'Jesse Metcalfe', 'Joel Bryant', 'Helen Hunt', 'Dennis Weaver',
#         'Brad Dourif', 'Julia Whelan', 'Hallee Hirsh', 'Mackenzie Rosman',
#         'Eileen Davidson', 'Debbie Rochon', 'Tiffany Shepis',
#         'William Shatner', 'Jared Padalecki', 'Danielle Panabaker',
#         'Carolyn Jones', 'Vincent Price', 'Alyssa Milano', 'Martin Kemp',
#         'Christopher Lee', 'Dennis Waterman', 'Jeff Seymour',
#         'Roger Moore', 'James Caan', 'David Strathairn', 'Lukas Haas',
#         'Lisa Bonet'], dtype=object),
#  193: array(['David Warner', 'Yaphet Kotto', 'Donald Moffat', 'Alex McArthur',
#         'Ed Harris', 'Eduardo Noriega', 'Jason Isaacs', 'January Jones',
#         'Kelli Williams', 'Amy Jo Johnson', 'Kurt Max Runte',
#         'Henry Fonda', 'Anthony Quinn', 'Dorothy Malone', 'Mary Woronov',
#         'Lori Singer', 'Richard E. Grant', 'Gregory Peck', 'Omar Sharif',
#         'Telly Savalas', 'Finola Hughes', 'Jeremy Ratchford',
#         'Matt Frewer', 'Heather McComb', 'Roger Moore', 'Jane Seymour',
#         'Christopher Lee', 'Anne Hathaway', 'Derek Jacobi', 'Clint Howard',
#         'Ona Grauer', 'Ben Browder', 'Michael Shanks', 'Amanda Tapping',
#         'Christopher Judge', 'Richard Dreyfuss', 'James Spader',
#         'Nikolai Binev', "Peter O'Toole", 'Armand Assante', 'Simon Yam',
#         'Daniel Wu', 'Leon Dai', 'Chen Yao', 'Samantha Morton',
#         'Alexandra Maria Lara', 'Koen De Bouw', 'Burt Lancaster',
#         'Ben Gazzara', 'Kate Reid', 'Kate Nelligan', 'Willem Dafoe',
#         'Ray Liotta', 'Stephen Rea', 'Michelle Rodriguez', 'Jack Thompson',
#         'Matthew Le Nevez', 'Rutger Hauer', 'Gary Busey', 'Ice-T',
#         'Charles S. Dutton', 'Howie Mandel', 'Fred Savage', 'Joan Collins',
#         'Tim Conway', 'Sean Connery', 'Donald Sutherland', 'Paul Reubens',
#         'Kristy Swanson', 'Marsha Mason', 'Tim Matheson', 'Rik Mayall',
#         'Jason Bateman', 'Jennifer Garner', 'Michael Cera', 'Ellen Page',
#         'John Hurt', 'Tilda Swinton', 'Tom Hiddleston', 'Mia Wasikowska',
#         'Diane Lane', 'Kevin Bacon', 'Luke Wilson', 'Frankie Muniz',
#         'Christopher Kirby', 'Steve Buscemi', 'Thora Birch', 'Brad Renfro',
#         'Scarlett Johansson', 'Alec Baldwin', 'Shawn Hatosy', 'Amy Smart',
#         'Danny DeVito', 'Kevin Spacey', 'Peter Facinelli', 'Buster Keaton',
#         'Drake Bell', 'Sharon Stone', 'Craig T. Nelson', 'Prabhas',
#         'Joseph Gordon-Levitt', 'Natalie Portman', 'Rainn Wilson',
#         'Jackie Earle Haley', 'Tom Cruise', 'John P. Navin Jr.',
#         'Aishwarya Rai Bachchan', 'Martin Henderson', 'Marcos Palmeira',
#         'Luana Piovani', 'Matthew McConaughey', 'Channing Tatum',
#         'Olivia Munn', 'Beau Bridges', 'Jodie Foster', 'Rob Lowe',
#         'Paul McCrane', 'Dennis Quaid', 'Sarah Jessica Parker',
#         'Thomas Haden Church', 'Heather Graham', 'Taye Diggs', 'Sandra Oh',
#         'David Sutcliffe', 'Jennifer Aniston', 'Adriana Barraza',
#         'Sam Worthington', 'Anna Kendrick', 'Alexandra Neldel',
#         'Vincent Price', 'Peter Cushing', 'Anna Paquin', 'Ryan Phillippe',
#         'Riley Thomas Stewart', 'Helen Mirren', 'Abhimanyu Singh',
#         'Bob Hoskins', 'Andrea Riseborough', 'Mikhail Efremov',
#         'Angela Bassett', 'Loretta Devine', 'Marian Seldes', 'Kevin Kline',
#         'Katie Holmes', 'Paul Dano', 'Helena Bonham Carter',
#         'Paul Bettany', 'Naseeruddin Shah', 'Shah Rukh Khan', 'Val Kilmer',
#         'Elisabeth Harnois', 'William Sadler', 'Jacqueline Bisset',
#         'Mickey Rourke', 'Assumpta Serna', 'Bokeem Woodbine',
#         'Jada Pinkett Smith', 'Michel Piccoli', 'Susan Sarandon',
#         'Isabelle Huppert', 'Gaspard Ulliel', 'Stanley Baker',
#         'Jeanne Moreau', 'Virna Lisi', 'Daniel Brühl', 'Marta Etura',
#         'Michael Ironside', 'Patrick Bergin', 'Gwyneth Paltrow',
#         'Daniel Craig', 'George Maharis', 'Om Puri', 'Edward Herrmann',
#         'Cary Elwes', 'Kirsten Dunst', 'Eddie Izzard',
#         'Christopher Eccleston', 'Kate Winslet', 'Liam Cunningham',
#         'Rachel Griffiths', 'William Holden', 'José Ferrer',
#         'Marthe Keller', 'Julianne Moore', 'Steve Carell',
#         'Michael Shannon', 'Colin Firth', 'Nicholas Hoult',
#         'Matthew Goode', 'Sidney Poitier', 'Sammy Davis Jr.',
#         'Colin Farrell', 'Maggie Gyllenhaal', 'Kareena Kapoor',
#         'Xueqi Wang', 'You Ge', 'Bingbing Fan', 'Xiaoming Huang',
#         'Rupert Graves', 'Diane Farr', 'Michael Caine', 'David Bradley',
#         'Emily Mortimer', 'Gary Oldman', 'John Wayne', 'David Janssen',
#         'John C. Reilly', 'Lubna Azabal', 'Anthony Chau-Sang Wong',
#         'Francis Ng', 'Bruce Dern', 'Pam Grier', 'Cillian Murphy',
#         'Jakob Oftebro', 'Danica Curcic', 'Gil Bellows',
#         'Jennifer Lawrence', 'Lindsay Duncan', 'Chris Evans',
#         'Octavia Spencer', 'Omar Epps', 'Nia Long', 'Stanley Tucci',
#         'LL Cool J', 'Christian Bale', 'Josh Lucas', 'Justin Theroux',
#         'Claudio Amendola', 'Pierfrancesco Favino', 'Elio Germano',
#         'Charlton Heston', 'Lorne Greene', 'Robert Duvall', 'Sissy Spacek',
#         'Bill Murray', 'Lucas Black', 'Alfred Molina', 'Peter Sarsgaard',
#         'Carey Mulligan', 'Guy Pearce', 'Sienna Miller', 'Jimmy Fallon',
#         'Jessica Tandy', 'Dan Aykroyd', 'Morgan Freeman', 'Patti LuPone',
#         'Elizabeth Taylor', 'Richard Burton', 'George Segal',
#         'Ellen Burstyn', 'Carla Gugino', 'David Boreanaz',
#         'Clifton Collins Jr.', 'Philip Seymour Hoffman',
#         'Catherine Keener', 'Harvey Keitel', 'Barbara Hershey',
#         'Rita Wilson', 'Greg Kinnear', 'Maria Bello', 'Kathleen Quinlan',
#         'Sam Rockwell', 'Mischa Barton', 'Preity Zinta', 'Kiron Kher',
#         'Diane Ladd', 'Laura Dern', 'Lukas Haas', 'Michael Pitt',
#         'Dan Stevens', 'Christopher Abbott', 'Brendan Cowell',
#         'Steve Le Marquand', 'Gyton Grantley', 'Paul Sorvino',
#         'Joe Mantegna', 'William Forsythe', 'Tom Sizemore',
#         'Richard Schiff', 'Julie Bowen', 'Jamie Chung', 'Prince',
#         'Harry Dean Stanton', 'Eitarô Ozawa', 'Jose Coronado',
#         'Luis Tosar', 'Rodrigo De la Serna', 'Raúl Arévalo',
#         'Brian Benben', 'Dolph Lundgren', 'Eric Roberts', 'Linden Ashby',
#         'Gina Torres', 'Dennis Hopper', 'Jaime Pressly',
#         'Antonio Banderas', 'Dylan McDermott', 'Birgitte Hjort Sørensen',
#         'Malcolm McDowell', 'Sean Bean', 'Ving Rhames', 'Lauren Cohan',
#         'Jean-Claude Van Damme', 'John Ralston', 'Vinnie Jones',
#         'Faye Dunaway', 'Rene Auberjonois', 'Tommy Lee Jones',
#         'Brad Dourif', 'Zach Gilford', 'Nigel Bennett', 'Jeremy Northam',
#         'Lucy Liu', 'Timothy Webber', 'Lana Parrilla', 'Keanu Reeves',
#         'Christina Hendricks', 'Elle Fanning', 'Paul Winfield',
#         'Bill Pullman', 'Douglas Smith', 'Mel Harris', 'Lee Grant',
#         'Robert Englund', 'Stephen Ford', 'Aimee Teegarden',
#         'Ashley Greene', 'Lucas Till', 'Michael Paré', 'Mariel Hemingway',
#         'Mason Gamble'], dtype=object),
#  194: array(['Frances McDormand', 'Sophie Okonedo', 'Marton Csokas',
#         'Charlize Theron', 'Fredric March', 'Charles Laughton',
#         'Anthony Perkins', 'Richard Jordan', 'Charles Vanel',
#         'Liam Neeson', 'Uma Thurman', 'Geoffrey Rush', 'Hugh Jackman',
#         'Anne Hathaway', 'Amanda Seyfried', 'Bernard Blier',
#         'Kevin Costner', 'Christian Slater', 'Courteney Cox',
#         'Nicolas Cage', 'Sam Rockwell', 'Martin Sheen', 'Michael Douglas',
#         'Michael J. Fox', 'Annette Bening', 'Jessica Alba', 'Romany Malco',
#         'Bill Paxton', 'Denzel Washington', 'Mark Wahlberg',
#         'Shelley Winters', 'Frank Langella', 'Jeremy Irons',
#         'Dominique Swain', 'Neil Patrick Harris', 'Ben Affleck',
#         'Rosamund Pike', 'Bruce Willis', 'Giovanni Ribisi', 'Halle Berry',
#         'Harrison Ford', 'Willem Dafoe', 'Joaquim de Almeida',
#         'Danny Glover', 'Michael Peña', 'Giancarlo Esposito',
#         'Thomas Brodie-Sangster', 'Kaya Scodelario', "Dylan O'Brien",
#         'Harvey Keitel', 'Matthew McConaughey'], dtype=object),
#  195: array(['Irrfan Khan', 'Emma Stone', 'Andrew Garfield',
#         'Robert Downey Jr.', 'Chris Evans', 'Jeremy Renner',
#         'Scarlett Johansson', 'Sean Connery', 'Uma Thurman',
#         'Ralph Fiennes', 'Deborah Kerr'], dtype=object),
#  196: array(['Jonas Karlsson', 'Torkel Petersson', 'Brendan Coyle',
#         'Karoline Herfurth', 'Sylvester Stallone'], dtype=object),
#  197: array([], dtype=object),
#  198: array(['Jack Nicholson', 'Harry Dean Stanton', 'Ellen Barkin',
#         'Jack Thompson', 'John Polson', 'Bruce Willis', 'Dennis Farina',
#         'Sarah Jessica Parker', 'Tom Sizemore'], dtype=object),
#  199: array(['Lance Henriksen', 'Alexis Zibolis', 'Joan Crawford',
#         'Clark Gable', 'Daniel de Oliveira', 'Alice Braga', 'Michel Noher',
#         'Elisa Volpatto', 'Jean-Claude Van Damme', 'Dolph Lundgren',
#         'Ray Milland', 'Rosemary Murphy', 'Elisabeth Moss', 'Tom Malloy',
#         'Terence Stamp', 'Kim Basinger', 'Val Kilmer'], dtype=object)}
